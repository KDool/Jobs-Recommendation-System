# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>EDA Analysis</h2>

# %%
# Read JD dataset from CSV files, Run EDA Analysis
list_data_fields = ['LinkedIn/output/JD_Business Intelligence.csv','LinkedIn/output/JD_Data Analyst.csv',
                    'LinkedIn/output/JD_Data Architect.csv','LinkedIn/output/JD_Data Engineer.csv',
                    'LinkedIn/output/JD_Data Scientist.csv','LinkedIn/output/JD_Business Analyst.csv','LinkedIn/output/JD_Database Administrator.csv']

list_software_fields = ['LinkedIn/output/JD_Back End Developer.csv','LinkedIn/output/JD_Back-end Developer.csv',
                        'LinkedIn/output/JD_DevOps.csv','LinkedIn/output/JD_Front End Developer.csv','LinkedIn/output/JD_Front-end Developer.csv',
                        'LinkedIn/output/JD_Product Manager.csv','LinkedIn/output/JD_Software Engineer.csv','LinkedIn/output/JD_Tester.csv']

print(list_data_fields)
# Out:
# ['LinkedIn/output/JD_Business Intelligence.csv', 'LinkedIn/output/JD_Data Analyst.csv', 'LinkedIn/output/JD_Data Architect.csv', 'LinkedIn/output/JD_Data Engineer.csv', 'LinkedIn/output/JD_Data Scientist.csv', 'LinkedIn/output/JD_Business Analyst.csv', 'LinkedIn/output/JD_Database Administrator.csv']

# %%
def read_and_clean_single_role(input_path=''):
    df = pd.read_csv(input_path,sep='|')

    # Drop Null Values for description column
    df = df.dropna(axis=0,subset=['description'])

    # Remove the same description & company & jobTitle & location & type
    df = df.drop_duplicates(subset=['jobTitle','location','company','type','description'],keep='first')

    return df

# df = read_and_clean_single_role('../'+'LinkedIn/output/JD_Business Analyst.csv')
# df

# %%
def create_field_DataFrame(input_list = list):
    list_dfs=[]
    for item in input_list:
        print(item)
        df_tmp = read_and_clean_single_role('../'+item)
        list_dfs.append(df_tmp)

    df = pd.concat(list_dfs)
    df = df.reset_index()
    return df

# %%
df_DS = create_field_DataFrame(list_data_fields)
df_SW = create_field_DataFrame(list_software_fields)
# Out:
# LinkedIn/output/JD_Business Intelligence.csv
# LinkedIn/output/JD_Data Analyst.csv
# LinkedIn/output/JD_Data Architect.csv
# LinkedIn/output/JD_Data Engineer.csv
# LinkedIn/output/JD_Data Scientist.csv
# LinkedIn/output/JD_Business Analyst.csv
# LinkedIn/output/JD_Database Administrator.csv
# LinkedIn/output/JD_Back End Developer.csv
# LinkedIn/output/JD_Back-end Developer.csv
# LinkedIn/output/JD_DevOps.csv
# LinkedIn/output/JD_Front End Developer.csv
# LinkedIn/output/JD_Front-end Developer.csv
# LinkedIn/output/JD_Product Manager.csv
# LinkedIn/output/JD_Software Engineer.csv
# LinkedIn/output/JD_Tester.csv

# %%
df_DS
# Out:
#      index          id                                           jobTitle  \
# 0        0  2975673294  Data Engineer in Business Intelligence Team (B...
# 1        1  2993666500              Business Intelligence Intern, Kobiton
# 2        2  2975674182  Business Intelligence Developer, Product Team ...
# 3        3  2993740820  Business Intelligence (Edtech Company, Upto 10...
# 4        4  2945707463        Senior Business Intelligence Analyst (0824)
# ..     ...         ...                                                ...
# 499     16  2990265063     Database Administrator (DBA), based in Da Nang
# 500     17  3008519916         Junior/Senior Database Administrator (DBA)
# 501     18  2698740162             [Local Product] Database Administrator
# 502     19  2973389208  [Local Product] Database Administrator (MySQL,...
# 503     20  2990260544  Senior Database Administrator (DBA), based in ...
#
#                                         location                    company  \
# ...

# %%
df_SW
# Out:
#      index          id                                           jobTitle  \
# 0        0  3008981684                                 Back End Developer
# 1        1  2756860056                                 Back End Developer
# 2        2  3003497520             Back End Developer ( Junior - Senior )
# 3        3  2983100486                                 Back End Developer
# 4        5  2994254043                                 Back End Developer
# ..     ...         ...                                                ...
# 720    194  2690306027                                QC Manager (Tester)
# 721    195  3013792683                                 Tester Intern (HN)
# 722    196  2909863988                                 Tester Intern (HN)
# 723    197  2978634839                                Tester Intern (HCM)
# 724    198  3012239765  Software Test Engineer Intern (QA/QC/Tester), ...
#
#                                         location                   company  \
# ...

# %%
plt.figure(figsize=(15,13))

plt.xlabel("location")
plt.ylabel("Counts")
df_DS["location"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='location', ylabel='Counts'>

# %%
plt.figure(figsize=(15,13))

plt.xlabel("location")
plt.ylabel("Counts")
df_SW["location"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='location', ylabel='Counts'>

# %%
# Data Science most frequent & Least frequent Job Title
print("MOST FREQUENT: \n",df_DS['jobTitle'].value_counts()[:10].index.tolist())
print("LEAST FREQUENT: \n",df_DS['jobTitle'].value_counts()[-10:].index.tolist())
# Out:
# MOST FREQUENT:
#  ['Senior Business Analyst', 'Business Analyst', 'Data Engineer', 'Lead Business Analyst', 'Data Analyst', 'Senior Data Engineer', 'Senior Data Analyst', 'Senior Data Scientist', 'Data Scientist', 'Database Administrator']
# LEAST FREQUENT:
#  ['Junior/Senior Data Engineer (ETL, Python, Azure)', 'Big Data Engineer', 'ShopeeFood - Business Intelligence Analyst (Based in Kuala Lumpur)', 'Data Engineer, KMS Solutions(Da Nang)', '(Senior) Data Engineer - Seller Center', 'Mid/Senior Data Engineer', 'Senior Data Engineer, KMS Solutions (Ha Noi)', 'Data Engineer (Vietnamese only)', 'Senior Data Engineer (ETL, SQL, BI), based in Da Nang', 'Senior Database Administrator (DBA), based in Da Nang']

# %%
# Software most frequent & least freqent Job Title
print("MOST FREQUENT: \n",df_SW['jobTitle'].value_counts()[:10].index.tolist())
print("LEAST FREQUENT: \n",df_SW['jobTitle'].value_counts()[-10:].index.tolist())
# Out:
# MOST FREQUENT:
#  ['DevOps Engineer', 'Product Manager', 'Software Engineer', 'Software Tester', 'Senior Automation Tester', 'Back End Developer', 'Senior Software Engineer', 'Java Software Engineer', 'Senior Java Software Engineer', 'Tester']
# LEAST FREQUENT:
#  ['Software Engineering in Test, Front End (Bangkok Based, Relocation Provided) – All Level', 'Senior Software Engineer / Software Engineer', 'Fresher Python Software Engineer', 'Embedded Software Engineer (IoT Project)', 'GFG - Senior Software Engineer', 'Senior Software Engineer – Real-Time Microservices (Bangkok based, relocation provided)', 'Software Engineer (JavaScript & React JS)', 'Lead Software Engineer, Fullstack', 'Software Developer', 'Software Test Engineer Intern (QA/QC/Tester), based in Da Nang']

# %%
plt.figure(figsize=(7,7))
plt.xlabel("Data Science Job Title length")
plt.ylabel("No. of jobs")

df_DS['jobTitle'].str.len().hist()
# Out:
# <AxesSubplot:xlabel='Data Science Job Title length', ylabel='No. of jobs'>

# %%
plt.figure(figsize=(7,7))
plt.xlabel("Software Job Title length")
plt.ylabel("No. of jobs")

df_SW['jobTitle'].str.len().hist()
# Out:
# <AxesSubplot:xlabel='Software Job Title length', ylabel='No. of jobs'>

# %%
# Job Description Length
# Data Science, 
# visualizing title length

plt.figure(figsize=(7,7))
plt.xlabel("Data Science Job Description length")
plt.ylabel("No. of jobs")

df_DS['description'].str.len().hist()
# Out:
# <AxesSubplot:xlabel='Data Science Job Description length', ylabel='No. of jobs'>

# %%
# Job Description Length
# Data Science, 
# visualizing title length

plt.figure(figsize=(7,7))
plt.xlabel("Data Science Job Description length")
plt.ylabel("No. of jobs")

df_SW['description'].str.len().hist()
# Out:
# <AxesSubplot:xlabel='Data Science Job Description length', ylabel='No. of jobs'>

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /Users/vankhaido/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/vankhaido/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import contractions

# %%
df_DS['description'][10]
df_SW['description'][10]
# Out:
# "About the job\nJob Description\nWe are looking for 03 experienced Golang and NodeJS Backend Engineer to join our fast-growing company to work on building out our state-of-the-art platform that is built on blockchain technology.\n\nYour responsibilities will include designing and building our products from concept all the way to deployment.\n- Working closely with the project team to design, code, troubleshoot on features/bug fixes.\n- Write robust code with high maintainability and scalability in Golang or NodeJS languages\n- Optimize and develop new features on our microservices-based\n- Write and maintain high-quality technical documentation\n- Testing, and resolution of defects and performance issues\n- Integrating and designing Json APIs\n- Participate in regular Scrums and Sprint planning meetings\n- Contribute and support our team to maintain a great working environment for you and other team members.\n\nYour skills and experiences\n*Must have:\n- Solid Golang or NodeJS, Javas
# ...

# %%
df_DS['description'] = df_DS['description'].apply(lambda x: [contractions.fix(word) for word in x.split()])
df_SW['description'] = df_SW['description'].apply(lambda x: [contractions.fix(word) for word in x.split()])
df_DS.sample(10, random_state = 5)
df_SW.sample(10, random_state = 5)
# Out:
#      index          id                                           jobTitle  \
# 151     15  2995896270        Product Manager - Consumer Product Division
# 643    116  2980996818                                 Penetration Tester
# 721    195  3013792683                                 Tester Intern (HN)
# 230     95  2926108791        Senior Product Manager/Senior Brand Manager
# 131      3  2964686727                         Junior Front-end Developer
# 478    250  2971078581                 Senior Software Engineer - Android
# 712    186  3003488954                           Senior Automation Tester
# 661    135  2978641657                             QC - Automation Tester
# 244     11  2975680066  Software Engineer (Data Team/all Levels) (Bang...
# 72      51  2973965491                                SRE/DevOps Engineer
#
#                                         location  \
# 151  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 643                        Hanoi, Hanoi, Vietnam
# ...

# %%
#cocatenating items back into a single string
df_DS['description'] = [' '.join(map(str, l)) for l in df_DS['description']]
df_SW['description'] = [' '.join(map(str, l)) for l in df_SW['description']]

# %% [markdown]
# <h2>Contractions Library </h2>
# </p>converts word to its full form. For example, you'll --> you will </p>

# %% [markdown]
# <h2>Noise Cleaning</h2>

# %%
import regex as re

df_DS['description'] = df_DS['description'].str.lower()
df_DS['description'] = df_DS['description'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))
df_SW['description'] = df_SW['description'].str.lower()
df_SW['description'] = df_SW['description'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))
# df_DS.sample(10, random_state = 5)
# Out:
#      index          id                                           jobTitle  \
# 226     12  3008025856              Senior Data Scientist - Data Platform
# 292     45  3003454468             [HN] Business Analyst - Finance Domain
# 90      52  3004257866                            Market Research Analyst
# 373    126  3012950615                            Senior Business Analyst
# 273     26  2955115953                                   Business Analyst
# 416    169  2891711510                           Digital Business Analyst
# 493     10  2975668723  Senior NoSQL Database Administrator (Bangkok b...
# 234     20  2895688985                              Senior Data Scientist
# 111     74  2980161544                Business Intelligence/ Data Analyst
# 470    223  2997094160  Business Analyst/ Product Owner/ Product Manag...
#
#                                         location             company  \
# 226  Ho Chi Minh City, Ho Chi Minh City, Vietnam                TIKI
# ...

# %%
#nltk tokenize
df_SW['tokenized_desc'] = df_SW['description'].apply(word_tokenize)
df_DS['tokenized_desc'] = df_DS['description'].apply(word_tokenize)
df_DS.sample(10, random_state = 5)
# Out:
#      index          id                                           jobTitle  \
# 226     12  3008025856              Senior Data Scientist - Data Platform
# 292     45  3003454468             [HN] Business Analyst - Finance Domain
# 90      52  3004257866                            Market Research Analyst
# 373    126  3012950615                            Senior Business Analyst
# 273     26  2955115953                                   Business Analyst
# 416    169  2891711510                           Digital Business Analyst
# 493     10  2975668723  Senior NoSQL Database Administrator (Bangkok b...
# 234     20  2895688985                              Senior Data Scientist
# 111     74  2980161544                Business Intelligence/ Data Analyst
# 470    223  2997094160  Business Analyst/ Product Owner/ Product Manag...
#
#                                         location             company  \
# 226  Ho Chi Minh City, Ho Chi Minh City, Vietnam                TIKI
# ...

# %%
df_DS.sample(10, random_state = 5)

# %% [markdown]
# <h3>Detect language of each JD</h3>

# %%
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector
# import ran
import random


def create_lang_detector(nlp, name):
    return LanguageDetector()

def JD_detect_lang(text=''):
    n = random.random()
    nlp = spacy.load("en_core_web_sm")
    Language.factory("language_detector"+str(n), func=create_lang_detector)
    # nlp.remove_pipe('language_detector')
    nlp.add_pipe('language_detector'+str(n), last=True)
    nlp.remove_pipe('language_detector'+str(n))
    doc = nlp(text)
    # print(doc._.language)
    return doc._.language

text_10 = df_DS['description'][10]
# text_11 = df_DS['description'][11]

JD_detect_lang(text_10)
# JD_detect_lang(text_11)

# %%
def label_language_DataFrame(df:pd.DataFrame):

    lang_list = ['' for i in range(len(df))]
    df['language'] = lang_list
    # print(lang_list)
    for index, row in df.iterrows():
        while True:
            try:
                detect_result = JD_detect_lang(row['description'])
                break
            except:
                print("Random number error")
        df.at[index, 'language'] = detect_result['language']
        # row['language'] = detect_result['language']


    return df

label_language_DataFrame(df_DS)

# %%
label_language_DataFrame(df_SW)
# Out:
# {'language': 'en', 'score': 0.9999969813029311}
# {'language': 'vi', 'score': 0.99999998800804}
# {'language': 'vi', 'score': 0.9999979739293622}
# {'language': 'en', 'score': 0.9999971317014154}
# {'language': 'vi', 'score': 0.9999999162764653}
# {'language': 'en', 'score': 0.9999964990976172}
# {'language': 'en', 'score': 0.9999952422855697}
# {'language': 'en', 'score': 0.9999959367912065}
# {'language': 'vi', 'score': 0.9999987105266346}
# {'language': 'en', 'score': 0.9999975888082012}
# {'language': 'en', 'score': 0.999994528851056}
# {'language': 'en', 'score': 0.9999961127052583}
# {'language': 'en', 'score': 0.9999981078949962}
# {'language': 'en', 'score': 0.9999984383619249}
# {'language': 'en', 'score': 0.9999977759666961}
# {'language': 'en', 'score': 0.9999967326423278}
# {'language': 'en', 'score': 0.999997886315813}
# {'language': 'en', 'score': 0.9999972301820046}
# {'language': 'en', 'score': 0.9999961125431989}
# {'language': 'en', 'score': 0.9999974119854904}
# ...

# %%
# initializing Stop words libraries
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vankhaido/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Before removing checking occurances of stopwords in article content
def plot_top_stopwords_barchart(text):
    stop=set(stopwords.words('english'))
    
    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]
    from collections import defaultdict
    dic=defaultdict(int)
    for word in corpus:
        if word in stop:
            dic[word]+=1
            
    top=sorted(dic.items(), key=lambda x:x[1],reverse=True)[:10]
    x,y=zip(*top)
    plt.figure(figsize=(10,10))
    plt.bar(x,y)

plot_top_stopwords_barchart(desc_df['description'])

# %%
import seaborn as sns
from collections import  Counter

def plot_top_non_stopwords_barchart(text):
    stop=set(stopwords.words('english'))
    
    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    counter=Counter(corpus)
    most=counter.most_common()
    x, y=[], []
    for word,count in most[:50]:
        if (word not in stop):
            x.append(word)
            y.append(count)
    plt.figure(figsize=(10,10))
    sns.barplot(x=y,y=x)

plot_top_non_stopwords_barchart(desc_df['description'])

# %%
record = df_DS.loc[df_DS['id'] == 3003454468]
record
# Out:
#      index          id                                jobTitle  \
# 292     45  3003454468  [HN] Business Analyst - Finance Domain
#
#                   location  company       type  \
# 292  Hanoi, Hanoi, Vietnam  Base.vn  Full-time
#
#                                            description  \
# 292  about the job sứ mệnh của base là xây dựng một...
#
#                                         tokenized_desc
# 292  [about, the, job, sứ, mệnh, của, base, là, xây...

# %%
df_DS
