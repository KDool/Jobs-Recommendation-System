# %%
from numpy import insert
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from time import sleep
import csv
import requests
import pymongo


def login():
      sleep(2)
      url = 'https://www.linkedin.com/login'
      driver.get(url)
      print('- Finish initializing a driver')
      sleep(1)

      # Task 1.2: Import username and password
      credential = open('credentials.txt',encoding="utf8")
      line = credential.readlines()
      username = line[0]
      password = line[1]
      print('- Finish importing the login credentials')
      sleep(1)

      # Task 1.2: Key in login credentials
      email_field = driver.find_element_by_id('username')
      email_field.send_keys(username)
      print('- Finish keying in email')
      sleep(3)

      password_field = driver.find_element_by_name('session_password')
      password_field.send_keys(password)
      print('- Finish keying in password')
      # sleep(3)

      # Task 1.2: Click the Login button
      # signin_field = driver.find_element_by_xpath('//*[@id="organic-div"]/form/div[3]/button')
      # signin_field.click()
      # sleep(1.5)

      print('- Finish Task 1: Login to Linkedin')

      # Task 1.3: Check if the login is successful

def getUserProfile(id=''):
    driver.get('https://www.linkedin.com/in/' + id)
    name = ''
    role = ''
    name = driver.find_elements_by_class_name('text-heading-xlarge')[0].text

    role = driver.find_element_by_css_selector('#ember37 > div.ph5 > div.mt2.relative > div:nth-child(1) > div.text-body-medium.break-words').text
    # print(role)
    sleep(3)
    skill_list = getSkills(id)
    # sleep(2)
    return name,role,skill_list


def getExperience(id=''):
    driver.get('https://www.linkedin.com/in/' + id +'/details/experience')
    experience = []
    page_source =  BeautifulSoup(driver.page_source,'html.parser')
    
    list_experience = page_source.select('div.display-flex.flex-row.justify-space-between')
    # print("LENGTH: ", len(list_experience))

    count = 0
    for item in list_experience:
        item_hidden = item.find_all('span',{'aria-hidden':'true'})
        count += 1
        # print("COUNT: ", count)
        exp = ''
        for i in item_hidden:
            exp = exp + i.text + ','
        exp = exp[:-1]
        experience.append(exp)
    skill_list = getSkills(id)
    return experience,skill_list

def getEducation(id=''):
    driver.get('https://www.linkedin.com/in/' + id +'/details/education')
    education = []
    page_source =  BeautifulSoup(driver.page_source,'html.parser')
    
    list_experience = page_source.select('div.display-flex.flex-row.justify-space-between')
    # print("LENGTH: ", len(list_experience))

    count = 0
    for item in list_experience:
        item_hidden = item.find_all('span',{'aria-hidden':'true'})
        count += 1
        # print("COUNT: ", count)
        exp = ''
        for i in item_hidden:
            exp = exp + i.text + ','
        exp = exp[:-1]
        education.append(exp)
    
    skill_list = getSkills(id)
    return education,skill_list


def getSkills(id=''):
    driver.get('https://www.linkedin.com/in/' + id +'/details/skills')
    # sleep(0.2)
    # driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # pvs-list__paged-list-item artdeco-list__item pvs-list__item--line-separated 
    sleep(0.6)
    skill_list = []
    page_source =  BeautifulSoup(driver.page_source,'html.parser')
    list_skill = page_source.select('span.mr1.t-bold')
    # print("LENGTH: ", len(list_skill))
    
    for item in list_skill:
        # print(item)
        item_list = item.find_all('span',{'aria-hidden':'true'})
        
        # print(item_list)
        for i in item_list:
            if i.text not in skill_list:
                skill_list.append(i.text)
    # print(skill_list)
    return skill_list

# Connect to Mongo DB
def connect():
    url='mongodb://mongoadmin:admin@13.67.48.201:27017/'
    myclient = pymongo.MongoClient(url)
    return myclient


def read_user_mongodb(myclient:pymongo.MongoClient):
    # Connect to MongoDB
    # Return list of userID
    import pandas as pd
    mydb = myclient['LinkedIn']
    mycol = mydb['UserIDs']
    mydoc = mycol.find() 
    result = list(mydoc)
    user_id_list = [item['_id'] for item in result]
    # df = pd.DataFrame(result['_id'])
    return user_id_list

def insert_a_record(myclient:pymongo.MongoClient,db='LinkedIn',collection='User_skills_profiles',data={}):
    mydb = myclient[db]
    mycol = mydb[collection]
    mycol.insert_one(data)

# %%
print('- Finish importing packages')
# DRIVER_PATH = '../driver/mac/chromedriver'
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(executable_path=ChromeDriverManager().install())
# driver = webdriver.Chrome(executable_path=DRIVER_PATH)
driver.maximize_window()
login()
sleep(2)
myclient = connect()
user_id_list = read_user_mongodb(myclient)
count_users = len(user_id_list)
# Out:
# [WDM] - ====== WebDriver manager ======
# - Finish importing packages
# [WDM] - Current google-chrome version is 101.0.4951
# [WDM] - Get LATEST chromedriver version for 101.0.4951 google-chrome
# [WDM] - Driver [C:\Users\admin\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# - Finish initializing a driver
# - Finish importing the login credentials
# - Finish keying in email
# - Finish keying in password
# - Finish Task 1: Login to Linkedin

# %%
for i in range(600,800):
    sleep(3)
    print("User number: ",i)
    name=''
    role = ''
    skills = []
    try:
        skills = getSkills(user_id_list[i])
    except:
        print("ERROR at ID: ",user_id_list[i])

    dict_user = {'_id':user_id_list[i],'name':name,'role':role,'skills':skills}
    print(dict_user)
    insert_a_record(myclient,'LinkedIn','User_skills_profiles',dict_user)
    # name,role,skills = getUserProfile(user_id_list[113])
    # dict_user = {'_id':user_id_list[i],'name':name,'role':role,'skills':skills}
    # print(dict_user)
# Out:
# User number:  400
# {'_id': 'madina-jumagulova-445b9b172', 'name': '', 'role': '', 'skills': ['Английский язык', 'Статистика', 'Высшая математика', 'Математика', 'Физика', 'LaTeX', 'Русский', 'Французский язык', 'Microsoft Power BI', 'Performance Dashboards', 'Business Analytics', 'Data Visualization', 'POWER BI', 'PostgreSQL', 'Microsoft SQL Server', 'Data Analysis', 'Data Structures']}
# User number:  401
# {'_id': 'khimbyrlee-camingue-4a482b56', 'name': '', 'role': '', 'skills': []}
# User number:  402
# {'_id': 'ACoAAC1-Hq8BUoSWJ9nACw6l1tCLPczS75BXojY', 'name': '', 'role': '', 'skills': ['Devwork.vn', 'IT Recruiter', 'Banking Academy of Vietnam', 'Independent Thinking', 'Communication', 'Listen', 'Share CV Hà Nội ', 'ACB - Asia Commercial Bank', 'Management and C-Level Jobs']}
# User number:  403
# {'_id': 'neeraj-srivastava-1a4aa840', 'name': '', 'role': '', 'skills': ['Databases', 'JavaScript', 'PL/SQL', 'Data Analysis', 'Data Structures', 'C++', 'C', 'Windows', 'Java', 'MySQL', 'Python (Programming Language)', 'Microsoft Power BI']}
# User number:  404
# {'_id': 'sandrine-nataprawira', 'name': '', 'role': '', 'skills': ['Java', 'SQL', 'C', 'JavaScript', 'Microsoft Visual Studio Code', 'HTML5', 'Cascading Style Sheets (CSS)', 'Microsoft SQL Server', 'Python (Programming Language)', 'English', 'Apache Spark', 'R (Programming Language)', 'Android Studio', 'PHP', 'Apache', 'Hadoop', 'Cloudera', 'Hive', 'Database Administration', 'Database Design']}
# User number:  405
# {'_id': 'namduongphan', 'name': '', 'role': '', 'skills': ['Public Speaking', 'Easily Adaptable', 'Time Management', 'Enthusiasm', 'Calming', 'Sports', 'Teaching', 'Communication', 'Presentations', 'Problem Solving', 'English', 'Persuasion', 'Creativity']}
# User number:  406
# {'_id': 'ACoAADZs-e4Bh-OxcLf9FtCVk5ZxYfJEVnztS7k', 'name': '', 'role': '', 'skills': ['Vietnam Economy in a Turbulent Global Environment Workshop', 'Graphic Designer', 'Graphic Design Intern', 'Color Me Academy ']}
# User number:  407
# {'_id': 'tienthanh21189', 'name': '', 'role': '', 'skills': []}
# User number:  408
# {'_id': 'gia-qu%E1%BB%B3nh-ph%E1%BA%A1m-96ba61195', 'name': '', 'role': '', 'skills': ['Communication', 'Microsoft Office', 'Leadership', 'Data Analytics', 'Social Media Marketing']}
# User number:  409
# {'_id': 'tranphuongthuy', 'name': '', 'role': '', 'skills': []}
# User number:  410
# {'_id': 'ACoAACsgnHgBmKXda6jsoS4XjhBAaWclp2GNdXA', 'name': '', 'role': '', 'skills': ['You both work at Hanoi University of Science and Technology', 'You both studied at Hanoi University of Science and Technology', "Ánh hasn't posted lately", 'Student', 'Hanoi University of Science and Technology', 'Microsoft Office', 'Research', 'C#', 'InnoLab Asia', 'ITviec', 'IT Professional Networking in Vietnam']}
# User number:  411
# {'_id': 'long-nguyen-56384121', 'name': '', 'role': '', 'skills': []}
# User number:  412
# {'_id': 'innovature-bpo-3b654810a', 'name': '', 'role': '', 'skills': []}
# User number:  413
# {'_id': 'dieu-trang-nguyen-9a794563', 'name': '', 'role': '', 'skills': ['Analysis', 'Data Analysis', 'Outsourcing', 'Teamwork', 'Microsoft Excel', 'Leadership', 'Business Analysis', 'PowerPoint', 'Microsoft Office', 'Team Management', 'Team Leadership', 'Databases', 'Time Management', 'Management', 'Project Management', 'Market Research', 'Access', 'Problem Solving', 'Sales', 'Customer Service', 'Human Resources', 'Market Analysis', 'Product Strategies', 'Sales&Marketing', 'Advertising', 'Human Resource Development', 'Customer Service Management', 'Team Development', 'Data Management', 'Customer Experience', 'Troubleshooting', 'Presentation Skills', 'Microsoft Access', 'Communication', 'Organization Skills', 'Team Motivation']}
# User number:  414
# {'_id': 'ACoAAA18x08Bfv_9rRNmZKDnAJvQcZjbZRTJ83E', 'name': '', 'role': '', 'skills': ["Dieu Trang hasn't posted lately", 'Service Solution ', 'Officience', 'Team leader-Senior Data Analyst', 'Quality Assurance', 'Trainer and coacher', 'Marketing-sales', 'EDI', 'Van Lang University', 'Analysis', 'Data Analysis', 'Outsourcing', 'Thanh Binh Nguy', 'HUONG Le (Candice)', 'VIPER', 'Viper', 'The Best Staff', 'the Best Team Leader', 'Chinese', 'English', 'PepsiCo', 'Axon', 'Vietnam Jobs']}
# User number:  415
# {'_id': 'minhhuyentran', 'name': '', 'role': '', 'skills': []}
# User number:  416
# {'_id': 'ledinhtu', 'name': '', 'role': '', 'skills': []}
# User number:  417
# {'_id': 'ACoAADP5muEBvowkK3gbrbS1dEF7fyVJ84JpQwo', 'name': '', 'role': '', 'skills': ['Digital Marketing', 'Đại học giao thông vận tải Hà Nội']}
# User number:  418
# {'_id': 'nguyenhungtuan', 'name': '', 'role': '', 'skills': []}
# User number:  419
# {'_id': 'raphael-durand-96892041', 'name': '', 'role': '', 'skills': ['Leadership', 'Public Speaking', 'Research', 'Social Media', 'PowerPoint', 'Event Planning', 'Social Networking', 'Microsoft Office', 'Nonprofits', 'Volunteer Management', 'Spanish', 'Microsoft Word', 'Blogging', 'Community Outreach', 'Microsoft Excel', 'Marketing', 'Data Analysis', 'Market Research', 'Qualitative Research', 'International Business', 'Merchandising', 'Media Sales', 'Fundraising', 'Email Marketing', 'SAS Programming', 'CRM', 'Facebook', 'SQL', 'Tableau', 'Google Analytics', 'Salesforce']}
# User number:  420
# {'_id': 'yago-de-carvalho-souto-a616abb1', 'name': '', 'role': '', 'skills': []}
# User number:  421
# {'_id': 'shabari-gadewar-a9480268', 'name': '', 'role': '', 'skills': []}
# User number:  422
# {'_id': 'josefin-beyer', 'name': '', 'role': '', 'skills': []}
# User number:  423
# {'_id': 'mark-anthony-badiao-b76806a3', 'name': '', 'role': '', 'skills': []}
# User number:  424
# {'_id': 'teresa-tang-853614b5', 'name': '', 'role': '', 'skills': ['Microsoft Office', 'Administrative Assistance', 'Management', 'Human Resources', 'Microsoft Word', 'Teamwork', 'Public Speaking', 'Interviews', 'Event Planning', 'PowerPoint', 'Microsoft Excel']}
# User number:  425
# {'_id': 'rana-s-gautam-82b4504b', 'name': '', 'role': '', 'skills': []}
# User number:  426
# {'_id': 'dinhoangminhngoc', 'name': '', 'role': '', 'skills': ['Strategic Planning', 'Research', 'Project Management', 'Social Media', 'Strategy', 'Microsoft Office', 'Event Management', 'Project Planning']}
# User number:  427
# {'_id': 'stephanieconejos', 'name': '', 'role': '', 'skills': []}
# User number:  428
# {'_id': 'ewakielbasa', 'name': '', 'role': '', 'skills': ['Microsoft Excel', 'Data Analysis', 'Reporting', 'SQL', 'Oracle HR', 'Microsoft Power BI', 'Tableau', 'Workday']}
# User number:  429
# {'_id': 'rebecca-schulte-a6938a30', 'name': '', 'role': '', 'skills': []}
# User number:  430
# {'_id': 'hongminhtri', 'name': '', 'role': '', 'skills': []}
# User number:  431
# {'_id': 'himanshu-ruhela', 'name': '', 'role': '', 'skills': ['Python', 'MySQL', 'Machine Learning', 'SQL', 'Data Science', 'C++', 'PostgreSQL', 'Django', 'TensorFlow', 'Git', 'Flask', 'Tableau', 'HTML', 'Cascading Style Sheets (CSS)', 'LaTeX', 'Database Management System (DBMS)', 'Computer Vision', 'Optical Character Recognition (OCR)', 'Adobe Photoshop', 'Computer Hardware', 'Economics', 'Model United Nations', 'Research', 'Case Studies', 'Reporting', 'Creative Writing', 'Leadership', 'Public Speaking']}
# User number:  432
# {'_id': 'lu-zhang-868551154', 'name': '', 'role': '', 'skills': []}
# User number:  433
# {'_id': 'vikashpateshwari', 'name': '', 'role': '', 'skills': ['ruby', 'Ruby on Rails', 'python', 'Django', 'Project Management', 'Microsoft Office', 'Leadership', 'Microsoft Word', 'C', 'Java', 'Programming', 'Android (Basics)', 'HTML', 'Cascading Style Sheets (CSS)', 'MySQL', 'Adobe Photoshop', 'Team Management', 'Omnet++', 'NumPy', 'pandas', 'Matplotlib', 'Scikit-Learn', 'Machine Learning Algorithms', 'Applied Machine Learning', 'Data Visualization', 'Spreadsheets', 'Google Sheets', 'Python (Programming Language)', 'Tableau', 'Informatica PowerCenter', 'Microsoft Excel', 'PostgreSQL', 'Tableau Online', 'Microsoft Power BI']}
# User number:  434
# {'_id': 'erika-kinjo', 'name': '', 'role': '', 'skills': []}
# User number:  435
# {'_id': 'gustavo-virgilio-joaquim', 'name': '', 'role': '', 'skills': ['Python', 'Microsoft Power BI', 'Análise de pessoas', 'Desenvolvimento web', 'SQL', 'JavaScript', 'VBA (Visual Basic for Applications)', 'QlikView', 'Pandas (Software)', 'Automação robótica de processos (RPA)', 'SAS', 'ETL (Extração, transformação e carregamento)', 'Inteligência de negócios (BI)', 'Selenium', 'Geração de insights', 'Recursos humanos (RH)', 'Banco de dados', 'Microsoft Office']}
# User number:  436
# {'_id': 'maggiemarsh', 'name': '', 'role': '', 'skills': []}
# User number:  437
# {'_id': 'dustanl', 'name': '', 'role': '', 'skills': []}
# User number:  438
# {'_id': 'murhafk', 'name': '', 'role': '', 'skills': ['Business Intelligence', 'Big Data', 'Cloudera', 'Integration', 'Business Analysis', 'Business Process', 'Algorithms', 'ERP', 'Requirements Analysis', 'Data Modeling', 'Data Warehousing', 'Extract, Transform, Load (ETL)', 'Data Analysis', 'Web Services', 'Data Integration', 'Reporting & Analysis', 'SQL', 'Business Objects', 'SAP', 'Crystal Reports', 'SAP HANA', 'SAP Business One', 'Apache Spark', 'Spark', 'Hive', 'Tableau', 'Java', 'Databases', 'Microsoft SQL Server', 'Hadoop', 'Sap Design Studio', 'Python', 'Apache Flume', 'Microsoft Power BI', 'HBase', 'Apache NiFi', 'Apache Sqoop', 'NoSQL', 'Cloudera Impala', 'PySpark', 'Team Management', 'Teamwork']}
# User number:  439
# {'_id': 'yash-jain-5485a4111', 'name': '', 'role': '', 'skills': []}
# User number:  440
# {'_id': 'surya-shree', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'Statistical Data Analysis', 'PL/SQL', 'Machine Learning', 'Data Structures', 'Data Analysis', 'Public Speaking', 'Statistics', 'SQL', 'Microsoft Excel', 'Tableau', 'User Interface Design', 'Microsoft SQL Server', 'Data Science', 'Microsoft Word', 'HTML5', 'Cascading Style Sheets (CSS)']}
# User number:  441
# {'_id': 'psaffarzadeh', 'name': '', 'role': '', 'skills': []}
# User number:  442
# {'_id': 'canyu-yang-1022', 'name': '', 'role': '', 'skills': ['Microsoft Office', 'Microsoft Excel', 'Microsoft PowerPoint', 'Microsoft Word', 'Research', 'SQL', 'R', 'Python (Programming Language)', 'Teamwork', 'Data Analysis', 'Piano', 'SAS Programming', 'Apache Spark', 'Tableau', 'Amazon Web Services (AWS)', 'Flask']}
# User number:  443
# {'_id': 'calista-dyah-amalia-16b639117', 'name': '', 'role': '', 'skills': ['Administrative Assistance', 'Secretarial Skills', 'International Relations', 'Microsoft Office', 'Research', 'Event Planning', 'Database Administration', 'Project Management', 'International Political Economy', 'East Asian Studies', 'Japanese Culture', 'Economic Development', 'Teamwork', 'Leadership', 'Korean Culture', 'Human Resources', 'Human Resources (HR)', 'Financial Accounting']}
# User number:  444
# {'_id': 'yuejiateng', 'name': '', 'role': '', 'skills': []}
# User number:  445
# {'_id': 'simithashetty', 'name': '', 'role': '', 'skills': []}
# User number:  446
# {'_id': 'shashankreddybikkem', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'MySQL', 'Machine Learning', 'JavaScript', 'HTML', 'Cascading Style Sheets (CSS)', 'HTML5', 'Bootstrap', 'jQuery', 'JSON', 'Pandas (Software)', 'Content Management Systems (CMS)', 'NumPy', 'Tableau', 'Presto', 'HiveQL']}
# User number:  447
# {'_id': 'umesh-salunke-493a82171', 'name': '', 'role': '', 'skills': ['Business Analysis', 'Product Management', 'Data Science', 'Artificial Intelligence (AI)', 'Digital Marketing', 'Information Technology', 'Requirements Gathering', 'Requirements Analysis', 'Project Management', 'Graphic Design', 'Web Design', 'Customer Relationship Management (CRM)', 'Machine Learning', 'User Experience (UX)', 'Social Media Marketing', 'Search Engine Optimization (SEO)', 'Agile Methodologies', 'Strategic Planning', 'E-commerce', 'Software Development Life Cycle (SDLC)', 'Data Visualization', 'Python (Programming Language)', 'Microsoft Excel', 'Content Management Systems (CMS)', 'MySQL', 'Google Analytics', 'WordPress', 'JIRA', 'Figma (Software)', 'Blockchain', 'Visio', 'Trello', 'Microsoft Office', 'Tableau', 'Microsoft Power BI', 'Emotional Intelligence', 'Problem Solving']}
# User number:  448
# {'_id': 'ericson-mattoso', 'name': '', 'role': '', 'skills': ['Budget Estimating', 'Manage Client', 'Project Management', 'Project Coordination', 'Team Leadership', 'Project Planning', 'Quality Management', 'CSS', 'HTML', 'WordPress', 'HTML 5', 'CSS3', 'Microsoft Windows', 'Microsoft Excel', 'Microsoft Word', 'Microsoft PowerPoint', 'Desenvolvimento de sites', 'Inglês', 'Gestão de projetos', 'MySQL', 'Planejamento de projetos', 'PMI (Project Management Institute)', 'Scrum', 'Web Development', 'Estratégia digital', 'Mídia digital', 'Análise de sistemas', 'Estratégia empresarial', 'Metodologia PMBOK', 'HTML5', 'JavaScript', 'Microsoft Project', 'Java', 'Microsoft Office', 'Sistemas operacionais', 'SQL', 'Adobe Illustrator', 'Banco de dados', 'Liderança de equipe']}
# User number:  449
# {'_id': 'parimala-konduru', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'Django', 'Data Structures', 'Big Data', 'Java', 'Hadoop', 'c', 'C++', 'JavaScript', 'HTML5', 'Cascading Style Sheets (CSS)', 'Scala', 'jQuery', 'Bootstrap', 'RESTful WebServices', 'MySQL', 'Apache Pig', 'Hive']}
# User number:  450
# {'_id': 'isha-narsaria', 'name': '', 'role': '', 'skills': ['Management', 'Microsoft Excel', 'Microsoft Office', 'Microsoft Word', 'Customer Service']}
# User number:  451
# {'_id': 'saranavarromedina', 'name': '', 'role': '', 'skills': []}
# User number:  452
# {'_id': 'mohamed-el-sobkey-444621153', 'name': '', 'role': '', 'skills': ['Data Analysis', 'الذكاء الاصطناعي', 'Volunteering', 'Cybersecurity', 'Security', 'Computer Networking', 'Engineering', 'Software', 'C++']}
# User number:  453
# {'_id': 'thuyngocpham', 'name': '', 'role': '', 'skills': []}
# User number:  454
# {'_id': 'tom-doll', 'name': '', 'role': '', 'skills': []}
# User number:  455
# {'_id': 'esther-idowu-139b74188', 'name': '', 'role': '', 'skills': ['Leadership', 'Microsoft Excel', 'Analytical Skills', 'Digital Marketing', 'Python (Programming Language)', 'Data Science', 'Data Analysis', 'Microsoft Office', 'Artificial Intelligence (AI)', 'k-means clustering', 'Flask', 'Teamwork', 'Cluster Analysis', 'Machine Learning Algorithms']}
# User number:  456
# {'_id': 'lucas-reis-41bb13184', 'name': '', 'role': '', 'skills': ['SQL', 'Python', 'Business analytics', 'Análise de rede', 'Microsoft Excel', 'Google Analytics', 'Microsoft Power BI', 'Inglês', 'Google Data Studio', 'Google Sheets']}
# User number:  457
# {'_id': 'leanna-c-98796973', 'name': '', 'role': '', 'skills': ['Human Resources', 'Onboarding', 'Project Management', 'Background Checks', 'Data Analysis', 'Research', 'Vendor Management', 'Payroll', 'Microsoft Office', 'PeopleSoft', 'Microsoft Excel', 'PowerPoint', 'Google Adwords', 'Google Analytics', 'ADP', 'Python (Programming Language)', 'Adobe XD', 'python', 'Tableau', 'Training', 'Interviews', 'Ultipro', 'iCIMS', 'Bing Ads', 'Unemployment Claims', 'Boolean Searching', 'Data Analytics', 'EEO Reporting', 'Google Sheets', 'ServiceNow', 'Jira', 'Applicant Tracking Systems', 'SQL', 'Looker (Software)', 'R (Programming Language)', 'Public Speaking', 'Leadership']}
# User number:  458
# {'_id': 'le-thao-rita-55041647', 'name': '', 'role': '', 'skills': []}
# User number:  459
# {'_id': 'hang-do-146688170', 'name': '', 'role': '', 'skills': ['Team Leadership', 'Personality Styles', 'Team Motivation']}
# User number:  460
# {'_id': 'sadaa-sree-r-949a14147', 'name': '', 'role': '', 'skills': []}
# User number:  461
# {'_id': 'amruth-g-434138147', 'name': '', 'role': '', 'skills': []}
# User number:  462
# {'_id': 'asgar-ahmad-82b28626', 'name': '', 'role': '', 'skills': []}
# User number:  463
# {'_id': 'trieudi-vo', 'name': '', 'role': '', 'skills': ['Machine Learning', 'PySpark', 'Consumer Financing', 'Data Mining', 'Statistics', 'Data Analysis', 'Econometrics', 'Economics', 'Cross Selling', 'Underwriting', 'Customer Relationship Management (CRM)', 'Python', 'Hadoop', 'R', 'Microsoft Office', 'Tableau', 'PL/SQL', 'Apache Airflow', 'Apache Zeppelin', 'Apache NiFi', 'Scorecard', 'Neural Networks', 'Snowflake']}
# User number:  464
# {'_id': 'sumanpreet-daisy-kaur-055a7130', 'name': '', 'role': '', 'skills': ['Troubleshooting', 'Networking', 'Linux', 'Databases', 'Operating Systems', 'C++', 'Microsoft Office', 'Windows', 'MySQL', 'HTML', 'C', 'Microsoft Excel', 'Matlab', 'Oracle', 'ASP.NET', 'VB.NET', 'PL/SQL', 'Technical Support', 'SQL', 'Requirements Gathering', 'Data Analysis', 'Customer Service', 'Reporting', 'MS Excel', 'SQL Server Reporting Services (SSRS)']}
# User number:  465
# {'_id': 'michelonesti', 'name': '', 'role': '', 'skills': []}
# User number:  466
# {'_id': 'manisha-panigrahi-2b4723199', 'name': '', 'role': '', 'skills': ['Data Analysis', 'Data Analytics', 'SQL', 'Data Science', 'Data Management', 'Microsoft Excel', 'Business Analysis', 'Data Collection', 'Data Visualization', 'Tableau', 'Project Management', 'Project Engineering', 'Financial Analysis']}
# User number:  467
# {'_id': 'hanh-phan-1b06725a', 'name': '', 'role': '', 'skills': []}
# User number:  468
# {'_id': 'amalsebastian13', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'Microsoft Excel', 'MySQL', 'Programming', 'Data Science', 'Video Editing', 'Financial Analysis', 'Editing', 'Design', 'Artificial Intelligence (AI)', 'Analytical Skills', 'Data Analysis', 'Business Analysis', 'Adobe Photoshop', 'HTML', 'SQL', 'Cloud Engineering', 'Data Engineering']}
# User number:  469
# {'_id': 'iacopo-biondini-6a9191a8', 'name': '', 'role': '', 'skills': []}
# User number:  470
# {'_id': 'saadrehman97', 'name': '', 'role': '', 'skills': ['R (Programming Language)', 'MySQL', 'Microsoft Excel', 'Data Analysis', 'Statistics', 'Econometrics', 'Economics', 'Mathematics', 'Public Policy', 'Psychology', 'Human Resources (HR)', 'Content Writing', 'Web Content Writing', 'Marketing', 'International Trade', 'R', 'Stata', 'Microsoft Office', 'Python', 'SQL', 'Teaching', 'Data Analytics', 'Management', 'Communication']}
# User number:  471
# {'_id': 'musab-belahouel', 'name': '', 'role': '', 'skills': []}
# User number:  472
# {'_id': 'hai-ly-ngo-3174a052', 'name': '', 'role': '', 'skills': ['ArcGIS', 'Recherche', 'SIG', 'GIS', 'Microsoft Office', 'Analyse de données', 'Géographie', 'Spatial Analysis', 'Cartography', 'Remote Sensing', 'Data Analysis', 'ERDAS Imagine', 'Research', 'Geography', 'MapInfo', 'Spatial Databases', 'ArcView', 'Geomatics', 'GPS', 'Erosion', 'Hydrologic Modeling', 'XLSTAT', 'Surfer', 'OpenLayers', 'Web Applications', 'Quantum GIS', 'Drupal', 'PHP', 'HTML', 'PostgreSQL', 'Adobe Photoshop', 'Python (Programming Language)']}
# User number:  473
# {'_id': 'ank-goyal', 'name': '', 'role': '', 'skills': ['Microsoft Office', 'Microsoft Excel', 'Microsoft Word', 'Web Development', 'C++', 'C', 'C (Programming Language)', 'PowerPoint', 'SQL', 'JavaScript', 'Python (Programming Language)', 'Data Science', 'MySQL', 'Front-end Development', 'Leadership', 'Project Management', 'Customer Service', 'Microsoft PowerPoint', 'Public Speaking', 'Cascading Style Sheets (CSS)', 'Machine Learning', 'HTML', 'PHP', 'Pandas (Software)', 'Communication', 'Teamwork']}
# User number:  474
# {'_id': 'maihuynhdw', 'name': '', 'role': '', 'skills': ['Business Intelligence', 'Data Warehousing', 'Microsoft SQL Server', 'ERP', 'Requirements Analysis', 'Analysis', 'Business Analysis', 'SQL', 'Business Process', 'Software Development', 'ETL', 'Databases', 'Software Project Management', 'Enterprise Resource Planning (ERP)', 'Testing', 'Data Analysis', 'SSIS', 'AX', 'Data Mining', 'Data Science', 'OLAP', 'SSAS', 'Startup Development', 'Startup Marketing', 'Start-ups', 'Navision', 'IBM Cognos', 'DB2', 'R', 'Trello', 'Unified Modeling Language (UML)', 'Viso', 'Visio', 'Power BI', 'Tableau', 'Cube', 'Teamwork']}
# User number:  475
# {'_id': 'mai-l%C3%AA-0515a9142', 'name': '', 'role': '', 'skills': ['Proficient in Word, Excel, Power Point', 'Social spirit, open-mind and love communication ', 'Be careful to work, sincere and hard working']}
# User number:  476
# {'_id': 'anh-le-2382947b', 'name': '', 'role': '', 'skills': ['Teamwork', 'Legal Research', 'Legal Writing', 'Corporate Law', 'Research', 'Data Analysis', 'Translation', 'Microsoft Office', 'Stata', 'Teaching', 'Leadership', 'Communication', 'Presentation Skills', 'Customer Service', 'Customer Marketing']}
# User number:  477
# {'_id': 'ngochang105', 'name': '', 'role': '', 'skills': ['Job Search', 'Data Analysis', 'Team Building', 'Customer Service', 'Change Management', 'Microsoft Excel', 'Marketing', 'Teamwork', 'Team Leadership', 'Problem Solving']}
# User number:  478
# {'_id': 'vaibhav-singh-2607b5169', 'name': '', 'role': '', 'skills': ['Team Leadership', 'Public Speaking', 'Python (Programming Language)', 'Event Management', 'Sales', 'Business Development', 'Social Media Marketing', 'Digital Marketing', 'Marketing', 'Social Media', 'E-commerce', 'Marketing Strategy', 'Event Planning', 'Cascading Style Sheets (CSS)', 'HTML', 'Microsoft Office', 'WordPress', 'Microsoft PowerPoint', 'Microsoft Excel', 'SQL', 'Presentation Skills', 'HTML Scripting', 'Databases', 'Leadership', 'Communication']}
# User number:  479
# {'_id': 'hoangducanh', 'name': '', 'role': '', 'skills': ['Data Analysis', 'Data Mining', 'SAS programming', 'SPSS', 'R', 'Microsoft Excel', 'Econometric Modeling', 'SAS Base', 'Weka', 'Microsoft Word', 'Google Analytics', 'LaTeX', 'PowerPoint', 'Stata', 'Gretl', 'Edraw', 'VBA', 'GIMP', 'Photoshop', 'Leadership', 'Decision Trees', 'Time Management', 'Mobile Applications', 'Mobile Marketing', 'Mobile Internet', 'Economics', 'Econometrics', 'Research', 'Market Research', 'User Experience', 'User Interface', 'Business Analysis', 'SAS', 'Visio', 'Microsoft PowerPoint', 'Microsoft Office', 'Teamwork', 'Problem Solving', 'Communication', 'Search', 'Analysis', 'Analytical Skills']}
# User number:  480
# {'_id': 'minhanhng', 'name': '', 'role': '', 'skills': []}
# User number:  481
# {'_id': 'wahaj-baig', 'name': '', 'role': '', 'skills': ['Leadership', 'Problem Solving', 'Research', 'Teamwork', 'Microsoft Office', 'Programming', 'Python (Programming Language)', 'Data Analysis', 'User-centered Design', 'Mathematics', 'C++', 'Curriculum Development', 'Critical Thinking', 'Arduino', 'Verilog', 'Maya', 'inVision', 'Jupyter', 'Avaya Products', 'Processing']}
# User number:  482
# {'_id': 'maianhnguyen93', 'name': '', 'role': '', 'skills': []}
# User number:  483
# {'_id': 'linh-ngo', 'name': '', 'role': '', 'skills': ['Microsoft Excel', 'Microsoft Office', 'Management', 'SQL', 'Microsoft Word', 'salesforce', 'Customer Service', 'Teamwork']}
# User number:  484
# {'_id': 'eqnguyen9', 'name': '', 'role': '', 'skills': []}
# User number:  485
# {'_id': 'albertodoncel', 'name': '', 'role': '', 'skills': ['Política', 'Contabilidad', 'Liderazgo', 'Microsoft Office', 'Planificación estratégica', 'Gestión de proyectos', 'Oratoria']}
# User number:  486
# {'_id': 'naomibrome', 'name': '', 'role': '', 'skills': ['Energy', 'Settlement', 'Data Analysis', 'Data Flow', 'Smart Metering', 'Electricity', 'Energy Industry', 'Third Party Relationships', 'Microsoft Excel', 'AAT', 'Agresso', 'Visio', 'Time Management', 'Customer Service', 'Research', 'Camera Operating', 'Video Editing', 'Adobe Audition', 'Retail', 'Audio Post Production', 'Interviewing Skills', 'Interview Preparation', 'Risk Assessment', 'Microsoft Office', 'PowerPoint', 'Microsoft Word', 'Final Cut Pro', 'Analytical Skills']}
# User number:  487
# {'_id': 'minh-tran-313a1163', 'name': '', 'role': '', 'skills': ['SAP ERP', 'SQL', '.NET Framework', 'Analysis', 'Business Analysis', 'Microsoft SQL Server', 'SQL Server Reporting Services (SSRS)', 'Linux', 'Access', 'Java', 'VB.NET', 'Microsoft Office', 'HTML', 'Microsoft Access', 'VBA', 'Windows', 'Visual Basic .NET (VB.NET)', 'SAP HANA', 'Networking']}
# User number:  488
# {'_id': 'dangnhatle', 'name': '', 'role': '', 'skills': []}
# User number:  489
# {'_id': 'tri-tran-dao', 'name': '', 'role': '', 'skills': []}
# User number:  490
# {'_id': 'jayoza2002', 'name': '', 'role': '', 'skills': []}
# User number:  491
# {'_id': 'hamza-khan-a5a7291a3', 'name': '', 'role': '', 'skills': ['User Interface Design', 'Android Development', 'Deep Learning', 'Business Analytics', 'Web Development', 'Data Warehousing', 'Flutter', 'Data Analytics', 'Interfaces', 'Android Studio', 'Dart']}
# User number:  492
# {'_id': 'crodriguezmunoz', 'name': '', 'role': '', 'skills': []}
# User number:  493
# {'_id': 'namhvu', 'name': '', 'role': '', 'skills': []}
# User number:  494
# {'_id': 'mainguyen95', 'name': '', 'role': '', 'skills': []}
# User number:  495
# {'_id': 'quang-nguyen-198a3511', 'name': '', 'role': '', 'skills': []}
# User number:  496
# {'_id': 'hrishikeshwarrier', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'Data Science', 'Machine Learning', 'Deep Learning', 'Data Analysis', 'Pandas (Software)', 'SQL', 'Linux', 'Java', 'Spring Framework', 'Elastic Stack (ELK)', 'Microsoft Power BI', 'English', 'Qlik Sense']}
# User number:  497
# {'_id': 'hoan-nguyen-6b5aa8a7', 'name': '', 'role': '', 'skills': ['Mining', 'Engineering', 'Project Planning', 'Minerals', 'Continuous Improvement', 'AutoCAD', 'Project Engineering', 'Surface Mining']}
# User number:  498
# {'_id': 'do-quyen-12971713a', 'name': '', 'role': '', 'skills': ['Finance', 'Data Analysis', 'Commercial Banking', 'Presentation Skills', 'Contemporary Dance']}
# User number:  499
# {'_id': 'pham-thuy-my-phuong', 'name': '', 'role': '', 'skills': ['Teamwork', 'Business Development', 'Leadership', 'Analytics', 'Logistics', 'Market Research', 'Data Analysis', 'Business Strategy', 'Microsoft Office', 'Customer Service', 'Team Leadership', 'Presentation Skills', 'Problem Solving', 'Team Management', 'Strategic Thinking', 'Presentations', 'English', 'Professional Responsibility', 'Personal Development', 'High Performer', 'Data Visualization', 'Microsoft Excel', 'Microsoft Power BI']}
# User number:  500
# {'_id': 'hungnguyen88', 'name': '', 'role': '', 'skills': []}
# User number:  501
# {'_id': 'marcela-guliciuc-todor-3bb767a6', 'name': '', 'role': '', 'skills': ['Teamwork', 'Public Speaking', 'Statistical Data Analysis', 'Time Management', 'SPSS', 'Microsoft Office', 'Microsoft Excel', 'Project Management', 'Punctuation', 'Quantitative Research', 'Qualitative Research', 'Research', 'Design Research']}
# User number:  502
# {'_id': 'raymant-raj-chaudhary', 'name': '', 'role': '', 'skills': ['Unsupervised Learning', 'Data Science', 'Machine Learning', 'Data Cleaning', 'Python (Programming Language)', 'Tableau', 'MySQL', 'Microsoft Excel', 'Exploratory Data Analysis', 'Supervised Learning', 'Database Management System (DBMS)', 'Data Analytics', 'Data Mining', 'Data Visualization', 'Databases', 'Statistical Modeling', 'Communication', 'Mathematics', 'Business insights', 'Statistics', 'Statistical Data Analysis', 'Statistical Analysis', 'Natural Language Processing (NLP)', 'Data Analysis', 'Deep Learning', 'SQL', 'Microsoft office', 'Microsoft PowerPoint', 'Microsoft Word', 'TensorFlow', 'Keras']}
# User number:  503
# {'_id': 'ramesh-baskaran-49253a', 'name': '', 'role': '', 'skills': []}
# User number:  504
# {'_id': 'ACoAAAAUNS4BPWqXlCQRqUxwhZTZMtfxoPncpcY', 'name': '', 'role': '', 'skills': ['Senior Advisor(Banking)- Assigned as PMO for a Strategic Digital initiative@Techcombank, Hanoi', 'resolve computing services', 'Consultant & Advisor - Technology Solutions', 'Managing Director', 'Head of Special Projects - CEO Office', 'Head of Financial Control - Asia, GBM Risk & Finance Technology', 'Standard Chartered Bank', 'Head of Solutions Delivery - Enterprise Information Management', 'Sr. Project Manager - Wholesale Bank Basel 2 Program, Credit Risk', 'University at Buffalo School of Management, The State University of New York', 'Nanyang Technological University Singapore', 'Madras Christian College', 'Managing Your Personal Finances', 'English', 'Tamil']}
# User number:  505
# {'_id': 'yan-nguyen-365378142', 'name': '', 'role': '', 'skills': ['Presentation Skills', 'Team Management', 'Problem Solving', 'Customer Service', 'People Development']}
# User number:  506
# {'_id': 'chilinhpham', 'name': '', 'role': '', 'skills': []}
# User number:  507
# {'_id': 'mukesh-singh-b80b0533', 'name': '', 'role': '', 'skills': []}
# User number:  508
# {'_id': 'darrenme', 'name': '', 'role': '', 'skills': ['Data Science', 'Data Analysis', 'Machine Learning', 'Data Structures', 'Programming', 'Web Analytics', 'Mathematics', 'Algorithms', 'Financial Analysis', 'Financial Modeling', 'Strategic Planning', 'Financial Accounting', 'Data Visualization', 'Python (Programming Language)', 'SQL', 'JavaScript', 'Google Analytics', 'Microsoft Excel', 'Accountability', 'Written Communication', 'Data Analytics', 'Functional Programming', 'Financial Statement Analysis', 'Active Listening', 'Communication', 'Personal Development']}
# User number:  509
# {'_id': 'nguyentietnguyenkhoi', 'name': '', 'role': '', 'skills': ['Java', 'Python (Programming Language)', 'Object-Oriented Programming (OOP)', 'Teamwork', 'Organization Skills']}
# User number:  510
# {'_id': 'annabelleleanh', 'name': '', 'role': '', 'skills': []}
# User number:  511
# {'_id': 'tammyortizgrad', 'name': '', 'role': '', 'skills': ['Management', 'CRM', 'Recruiting', 'Technical Recruiting', 'Social Media', 'Customer Service', 'E-commerce', 'Consulting', 'Talent Acquisition', 'Networking', 'Social Networking', 'Leadership', 'Social Media Marketing', 'Sales', 'Training', 'Human Resources', 'Marketing', 'Email Marketing', 'Photoshop', 'SEO', 'Temporary Placement', 'Cold Calling', 'Customer Relationship Management (CRM)', 'SaaS', 'Salesforce.com', 'Applicant Tracking Systems', 'Team Leadership']}
# User number:  512
# {'_id': 'tinnguyen111199', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'Data Science', 'SQL', 'Machine Learning', 'Data Visualization', 'Data Analysis', 'Jupyter', 'SQL DB2', 'IBM Certified']}
# User number:  513
# {'_id': 'l%C3%AA-tr%E1%BB%8Bnh-33bb47217', 'name': '', 'role': '', 'skills': ['SQL', 'Extract, Transform, Load (ETL)', 'Data Marts', 'Statistical Data Analysis', 'Statistical Modeling']}
# User number:  514
# {'_id': 'veronicamoibiomedica', 'name': '', 'role': '', 'skills': ['Clinical Engineering', 'Predictive Analytics', 'Biomedical Engineering', 'Journalism', 'Research', 'Project management', 'Artificial intelligence', 'AI', 'HL7 Standards', 'Software Development Life Cycle (SDLC)', 'Software Development', 'Image Processing', 'Microsoft Word', 'Microsoft Excel', 'PowerPoint', 'Matlab', 'Microsoft Office', 'Microsoft Access', 'Microsoft Visio', 'Unified Modeling Language (UML)', 'Constructive Feedback', 'Team Building', 'Teaching', 'Team building', 'Time Management', 'Stress Management', 'DICOM', 'IHE', 'Microsoft Project', 'HTML', 'Cascading Style Sheets (CSS)', 'Picture Archiving and Communication System (PACS)', 'Python', 'Team Leadership', 'Public Speaking', 'Management', 'Team Management', 'Problem Solving', 'Creative Problem Solving', 'Collaborative Problem Solving', 'Multi-task & Handle High-volume Workloads', 'Lingua inglese', 'English']}
# User number:  515
# {'_id': 'ninathan', 'name': '', 'role': '', 'skills': []}
# User number:  516
# {'_id': 'rachael-jackson-14aab0114', 'name': '', 'role': '', 'skills': ['Problem Solving', 'Microsoft Office', 'Teamwork', 'Time Management', 'Communication', 'High Achiever', 'Microsoft Excel', 'Social Media', 'People Skills', 'Microsoft Word', 'PowerPoint', 'Data Analysis', 'Mobile Application Development', 'Objective-C']}
# User number:  517
# {'_id': 'donghyunshim', 'name': '', 'role': '', 'skills': ['R', 'Python ', 'Microsoft Excel', 'Data Analysis', 'Microsoft PowerPoint', 'Microsoft Word', 'SQL', 'STATA', 'Java', 'Korean']}
# User number:  518
# {'_id': 'nguyen-ngoc-diep-jamie-795374137', 'name': '', 'role': '', 'skills': []}
# User number:  519
# {'_id': 'nguyenvunhanai', 'name': '', 'role': '', 'skills': ['Teamwork', 'Customer Service', 'Business Analysis', 'Data Analysis', 'Research', 'Sourcing', 'Sourcer', 'Searching']}
# User number:  520
# {'_id': 'giangthanh', 'name': '', 'role': '', 'skills': ['Teamwork', 'Microsoft Office', 'Microsoft Excel', 'Microsoft Word', 'PowerPoint', 'Customer Service', 'Social Media', 'Photoshop', 'Research', 'Public Speaking', 'English', 'Windows', 'Time Management', 'Event Planning', 'C++', 'Java', 'HTML', 'C', 'Matlab', 'AutoCAD']}
# User number:  521
# {'_id': 'ganapathi-kakkirala', 'name': '', 'role': '', 'skills': []}
# User number:  522
# {'_id': 'ACoAACYJv1IBXivdX8QF3Ql-WcywgsfWrDMq1WI', 'name': '', 'role': '', 'skills': ['Business Intelligence Engineer', 'AlmaBetter', 'Data Science Intern', 'Data Science Trainee', 'TheSmartBridge', 'Business Analyst', 'Student Mentor', 'Community Relations Intern', 'Technical Content Writer', 'Kakinada Institute of Engineering and Technology', 'Sri Surya junior college', 'Beulah prudential school', 'Data Visualization: Best Practices', 'Programming Foundations: Databases', 'How to Succeed in a Case Study Interview', 'Student Volunteer', 'Local guide', 'Smart Ammonia System for poultry farms', 'Smart Street light management', 'Lifi based speaker system', 'Internet of Things with IBM cloud', 'English', 'Hindi', 'Telugu']}
# User number:  523
# {'_id': 'bui-tam-52049453', 'name': '', 'role': '', 'skills': []}
# User number:  524
# {'_id': 'vy-tran-a587a4188', 'name': '', 'role': '', 'skills': ['Procurement', 'Purchase Orders', 'Cost Reduction', 'Strategic Sourcing', 'Supplier Development', 'Microsoft Office', 'Visual Basic for Applications (VBA)', 'Supplier Evaluation', 'Supplier Management', 'Supplier Performance', 'Analytical Skills', 'Critical Thinking', 'Contract Negotiation']}
# User number:  525
# {'_id': 'ritesh0812', 'name': '', 'role': '', 'skills': []}
# User number:  526
# {'_id': 'quanhdang', 'name': '', 'role': '', 'skills': []}
# User number:  527
# {'_id': 'linhnkng', 'name': '', 'role': '', 'skills': ['Data Analysis', 'Research', 'Project Management', 'Video Editing', 'Event Planning', 'Social Media', 'Graphic Design', 'Data Collection', 'Quantitative Analytics', 'Business Intelligence (BI)', 'Data Visualization', 'Product Management', 'Project Planning', 'R', 'Python', 'SQL', 'Tableau', 'Stata', 'IBM Cognos Analytics', 'Adobe Photoshop', 'Teaching', 'Adobe Illustrator', 'Microsoft Excel', 'MySQL', 'Figma (Software)', 'spaCy', 'TensorFlow', 'Keras', 'Language Teaching', 'Public Speaking', 'Teamwork', 'Leadership']}
# User number:  528
# {'_id': 'ACoAACQWhywBYvz75IY3aZeJWC8y5CZrv2v1EX8', 'name': '', 'role': '', 'skills': []}
# User number:  529
# {'_id': 'trangtrieu', 'name': '', 'role': '', 'skills': ['Analytical Skills', 'Performance Management', 'Business Strategy', 'Online Marketing', 'New Business Development', 'Marketing', 'Business Process Improvement', 'Digital Marketing', 'Microsoft Office', 'Google Analytics', 'Adobe Analytics', 'Problem Solving', 'Leadership', 'Negotiation', 'Management']}
# User number:  530
# {'_id': 'tallha-khan', 'name': '', 'role': '', 'skills': ['Social Media', 'Decision-Making', 'Strategy', 'Presentations', 'Problem Solving', 'Molecular Biology', 'Polymerase Chain Reaction (PCR)', 'DNA Extraction', 'Data Analysis']}
# User number:  531
# {'_id': 'mrdebaranjan', 'name': '', 'role': '', 'skills': []}
# User number:  532
# {'_id': 'alisha-david', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'SQL', 'SAS', 'Data Analysis', 'Machine Learning', 'Data Visualization', 'Data Mining', 'Data Science', 'Accountancy', 'Financial Accounting', 'Financial Analysis', 'Financial Reporting', 'Cost Accounting', 'Finance', 'Operations Management', 'Microsoft Office', 'R (Programming Language)', 'Github', 'Microsoft Azure', 'Jupyter Notebook', 'Data Analytics', 'Scikit learn', 'Accounting Management', 'Web Scraping', 'HTML ', 'Cascading Style Sheets (CSS)', 'Microsoft Excel', 'Communication']}
# User number:  533
# {'_id': 'vu-dinh', 'name': '', 'role': '', 'skills': ['Analytical Skills', 'Presentation Skills', 'Leadership', 'Teamwork', 'Product Management', 'Customer Relationship Management (CRM)', 'Data Analysis', 'Risk Management', 'Banking', 'Product Development']}
# User number:  534
# {'_id': 'lth8998', 'name': '', 'role': '', 'skills': []}
# User number:  535
# {'_id': 'shanoobpp', 'name': '', 'role': '', 'skills': []}
# User number:  536
# {'_id': 'huytran6995', 'name': '', 'role': '', 'skills': ['Financial Analysis', 'TOEIC', 'Communication', 'Interpersonal Skills', 'Microsoft Word', 'Teamwork', 'Organization Skills', 'Microsoft Office', 'Microsoft Excel']}
# User number:  537
# {'_id': 'yu408', 'name': '', 'role': '', 'skills': []}
# User number:  538
# {'_id': 'dkhoatran', 'name': '', 'role': '', 'skills': ['Project Management', 'Business Analysis', 'Requirements Analysis', 'Product Management', 'Agile Methodologies', 'Software Development', 'Scrum', 'SDLC', 'Business Process Improvement', 'Data Modeling', 'Wireframes', 'Software Documentation', 'User Acceptance Testing', 'Project Planning', 'Technical Documentation', 'Budgeting', 'Project Coordination', 'Online Advertising', 'Advertising', 'Mobile Advertising', 'SQL', 'UML', 'Microsoft SQL Server', 'JIRA', 'HTML', 'MySQL', 'Hubspot', 'Teamwork', 'Negotiation', 'Leadership', 'Management', 'Team Leadership', 'Problem Solving', 'Communication', 'Team Management']}
# User number:  539
# {'_id': 'lizm', 'name': '', 'role': '', 'skills': []}
# User number:  540
# {'_id': 'caio-bueno-leite-940b19129', 'name': '', 'role': '', 'skills': ['Microsoft Power BI', 'Python (Programming Language)', 'MySQL', 'SQL', 'R (Programming Language)', 'Data Analysis', 'Tableau', 'Analytical Skills', 'Microsoft Excel', 'Data Analytics', 'PySpark', 'Self Learning', 'Business Intelligence (BI)', 'Data Visualization', 'Amazon Web Services (AWS)', 'Big Data Analytics', 'Big Data', 'Industrial Engineering', 'Trabalho em equipe', 'Problem Solving', 'Cloud Computing', 'Project Management', 'Airflow', 'Six Sigma', 'Apache NiFi', 'Management']}
# User number:  541
# {'_id': 'ericpmwong', 'name': '', 'role': '', 'skills': ['Data Analysis', 'Machine Learning', 'Project Management', 'Business Strategy', 'SQL', 'Python (Programming Language)', 'Data Science', 'Scala', 'Statistical Modeling', 'Internal Audit', 'Management', 'Strategy', 'ISO 13485', 'Microsoft Excel', 'Deep Learning']}
# User number:  542
# {'_id': 'tanmay-annam2112', 'name': '', 'role': '', 'skills': ['Python', 'R', 'SQL', 'c++', 'Data Analytics', 'Panda', 'SciPy', 'NumPy', 'Relational Databases', 'Microsoft Office', 'Excel', 'Tableau', 'Microsoft Excel', 'Vlookup', 'Data Visualization', 'Probability Theory', 'Information Security', 'Project Management', 'Data Analysis', 'Management', 'Statistical Data Analysis', 'Pivot Tables', 'Marketing Management', 'Scikit-Learn', 'Data Mining', 'Big Data', 'Machine Learning', 'Neural Networks', 'Customer Relationship Management (CRM)', 'MySQL', 'Microsoft Access', 'Microsoft Power BI', 'Matlab', 'HTML', 'PHP', 'PhpMyAdmin', 'PostgreSQL', 'MYSQL', 'Public Speaking', 'Leadership', 'Team Leadership']}
# User number:  543
# {'_id': 'yeongbaebang', 'name': '', 'role': '', 'skills': ['Python', 'Aprendizado de máquina', 'SQL', 'Financial Analysis', 'Financial Planning', 'Ciência de dados', 'PostgreSQL', 'Tableau', 'Python (Programming Language)', 'Microsoft Power BI', 'Microsoft Excel', 'Process Improvement', 'Data Analytics', 'Web Scraping', 'Limpeza de dados', 'P&L Forecasting', 'Data Analysis', 'SciPy', 'NumPy', 'Scikit-Learn', 'Budget', 'MySQL', 'Microsoft Office', 'Seaborn']}
# User number:  544
# {'_id': 'sindhusha-kilaru', 'name': '', 'role': '', 'skills': ['Microsoft Office', 'Microsoft Excel', 'Microsoft PowerPoint', 'Business Intelligence (BI)', 'Microsoft SQL Server', 'Microsoft Power BI', 'SQL Server Integration Services (SSIS)', 'SQL Server Reporting Services (SSRS)', 'SQL Server Analysis Services (SSAS)', 'powerBI', 'SQL', 'Extract, Transform, Load (ETL)', 'Data Warehousing', 'Tableau']}
# User number:  545
# {'_id': 'linn%C3%A9a-mellander-7a589a1b', 'name': '', 'role': '', 'skills': ['Editing', 'English', 'Microsoft Office', 'Microsoft Excel', 'Python (Programming Language)', 'SQL', 'Data Analysis', 'Data Analytics', 'Exploratory Data Analysis', 'Probabilistic Models', 'Quantitative Research', 'Quantitative Analytics', 'Qualitative Research', 'Qualitative & Quantitative Research Methodologies', 'Qualitative Data', 'Qualitative Analysis', 'Microsoft PowerPoint', 'Growth']}
# User number:  546
# {'_id': 'aaron-burton-ab0b71122', 'name': '', 'role': '', 'skills': ['Innovative', 'Problem Solving', 'Competitive', 'Data Analysis', 'Project Management', 'Reporting & Analysis', 'Business Analysis', 'Business Planning', 'Workforce Management', 'Workforce Planning', 'Business Analytics', 'Analytics', 'Vendor Management', 'Microsoft Office', 'Microsoft Excel', 'Organization Skills', 'Active Listener', 'Public Speaking', 'Leadership', 'Customer Service', 'Team Building', 'Planning & Scheduling', 'Staff Scheduling', 'Workforce Analytics', 'Call Center Development', 'Workforce Performance', 'Accounting', 'Process Improvement', 'Business Process Improvement', 'Microsoft Power BI', 'SAP Business Warehouse (SAP BW)', 'Oracle Database', 'Team Leadership', 'Communication', 'Analytical Skills', 'Teamwork', 'Strategy']}
# User number:  547
# {'_id': 'svetlana-novgorodova-916a6257', 'name': '', 'role': '', 'skills': ['Data Analysis', 'SQL', 'Business Intelligence Tools', 'Event Management', 'Project Management', 'Adobe Photoshop', 'Microsoft Excel', 'Microsoft SQL Server', 'Presentations', 'Leadership Development', 'Team Management', 'Organizational Development', 'IT skills', 'QlikView', 'Power BI', 'Data Visualization', 'Python (Programming Language)']}
# User number:  548
# {'_id': 'gerard-hales', 'name': '', 'role': '', 'skills': []}
# User number:  549
# {'_id': 'nurshafiqah-farhana-480ba217a', 'name': '', 'role': '', 'skills': ['Data Analysis', 'Data Mining', 'Research and Development (R&D)', 'Oracle Database', 'SAS Programming', 'Microsoft Office', 'Python (Programming Language)', 'Microsoft Word', 'Microsoft Excel', 'Microsoft PowerPoint']}
# User number:  550
# {'_id': 'zilin-liu-04388516b', 'name': '', 'role': '', 'skills': ['Microsoft Office', 'Microsoft Excel', 'Human Resources (HR)', 'Training', 'Statistics', 'SPSS', 'Factor Analysis', 'Questionnaire Design', 'Data Analysis', 'People Analytics', 'Regression Analysis', 'ANOVA', 'R', 'Research']}
# User number:  551
# {'_id': 'hyunsoo-s-040111188', 'name': '', 'role': '', 'skills': ['데이터분석', '인사', '통계 데이터 분석', '머신러닝', '내부 커뮤니케이션', 'SQL', 'R', 'Python', '통계', 'HR analysis']}
# User number:  552
# {'_id': 'alejandrocifuentesferreira', 'name': '', 'role': '', 'skills': ['People Analytics', 'Project Management', 'Performance Management', 'Analytical Skills', 'Data Analysis', 'Business Strategy', 'Consulting', 'Investigación y desarrollo', 'Social Media', 'Redes sociales', 'Liderazgo', 'Recursos humanos', 'Selección de personal', 'Investigación', 'Recruiting', 'HR Management', 'Workforce Planning', 'Data Management', 'Data Mining', 'Statistical Data Analysis', 'Data Modeling', 'HR Policies', 'Databases', 'Microsoft Excel', 'SPSS', 'Microsoft Word', 'PowerPoint', 'Microsoft PowerPoint', 'Microsoft Office', 'SQL', 'Tableau', 'Human Resources Information Systems (HRIS)', 'Trabajo en equipo', 'Liderazgo de equipos', 'Teamwork', 'Management', 'Team Leadership', 'Inglés', 'English', 'Spanish']}
# User number:  553
# {'_id': 'yuriy-sidorov', 'name': '', 'role': '', 'skills': []}
# User number:  554
# {'_id': 'abdessamad-daoudi', 'name': '', 'role': '', 'skills': ['Gestion de projet', 'Data Mining', 'Machine Learning', 'Programming', 'SQL', 'Oracle Database', 'Python', 'C++', 'MATLAB', 'UML', 'QlikView', 'R', 'Java', 'KNIME (Konstanz Information Miner)', 'Orange datamining', 'Python (Programming Language)', 'Android Studio', 'Artificial Intelligence (AI)', 'Business Intelligence (BI)', 'Pyspark', 'Apprentissage automatique', 'Microsoft SQL Server', 'Python (langage de programmation)']}
# User number:  555
# {'_id': 'arkadiusz-zareba', 'name': '', 'role': '', 'skills': ['Reporting & Analysis', 'Microsoft Power BI', 'SQL', 'Google Data Studio', 'Microsoft Excel', 'Szkolenie nowych pracowników', 'Analiza danych', 'Administracja biurowa', 'Zdolności analityczne', 'Analizy finansowe', 'Wprowadzanie danych', 'Data Analysis', 'Data Visualization', 'Microsoft Office', 'SAP ERP', 'Praca zespołowa', 'Zarządzanie', 'Obsługa klienta', 'Training', 'Problem Solving', 'Time Management', 'Employee Training', 'Workday', 'System SAP', 'SAT', 'Raportowanie', 'CAE', 'Process Improvement', 'HR Analytics', 'HR Metrics', 'Creative Problem Solving']}
# User number:  556
# {'_id': 'lorena-manzano-diaz-2a716439', 'name': '', 'role': '', 'skills': ['Psychology', 'Data Analysis', 'Project Management', 'Research', 'Management Consulting', 'Science', 'Psychological Assessment', 'Design Research', 'Consulting', 'Data Visualization', 'Reporting & Analysis', 'UX', 'SPSS', 'Microsoft Office', 'Microsoft Excel', 'Python', 'SQL', 'Microsoft PowerPoint', 'Qualitative Research', 'Teaching', 'Training', 'Organizational Development', 'Leadership Development', 'Interviewing', 'Customer Service', 'People Analytics', 'Tableau', 'Leadership', 'Management', 'Teamwork', 'Team Leadership', 'Analytical Skills', 'English']}
# User number:  557
# {'_id': 'shimaa-elabd', 'name': '', 'role': '', 'skills': []}
# User number:  558
# {'_id': 'greeshma-p-a-079927204', 'name': '', 'role': '', 'skills': ['Tableau', 'Microsoft Excel', 'Python (Programming Language)', 'Data Analysis', 'Data Entry', 'Microsoft Word', 'Microsoft PowerPoint', 'C (Programming Language)', 'Microsoft SQL Server', 'PySpark', 'Hadoop', 'Visual Basic', 'LaTeX', 'R (Programming Language)']}
# User number:  559
# {'_id': 'danielalaginhasteixeira', 'name': '', 'role': '', 'skills': ['Oracle', 'Dashboard', 'Apex ', 'ETL (Extração, transformação e carregamento)', 'Website Development', 'SAP BO', 'Microsoft Excel', 'SQL', 'HTML', 'Matlab', 'PHP', 'Microsoft Office', 'C++', 'MySQL', 'JavaScript', 'CSS', 'XML', 'LabVIEW', 'Microsoft SQL Server', 'LaTeX', 'XSD', 'Octave', 'Continuous Process Improvement', 'Reporting', 'TIBCO', 'Data virtualization ', 'AJAX', 'XSLT', 'C (linguagem de programação)', 'Windows', 'Transparency']}
# User number:  560
# {'_id': 'poojabais', 'name': '', 'role': '', 'skills': ['Probability Theory', 'Statistical Data Analysis', 'Microsoft Excel', 'R', 'C (Programming Language)', 'C++', 'Project Management', 'Research', 'Data Analysis', 'Data Visualization', 'Python (Programming Language)', 'Data Science', 'Business Analysis', 'Database Management System (DBMS)', 'Management', 'Leadership', 'Microsoft Office', 'Public Speaking', 'Microsoft Azure', 'Tableau', 'Dashboard', 'Data Analytics', 'Database Administration', 'Brand Design', 'Visual Design', 'Statistics', 'Statistical Modeling', 'RStudio', 'Data Management', 'Data-driven Decision Making', 'Data Mining', 'SQL', 'Microsoft SQL Server', 'Anaconda', 'Seaborn', 'Python ', 'Databases', 'R (Programming Language)', 'R Shiny', 'Analytical Skills', 'Communication']}
# User number:  561
# {'_id': 'aleks-faynleyb', 'name': '', 'role': '', 'skills': []}
# User number:  562
# {'_id': 'sorravith-jaichuen-958255124', 'name': '', 'role': '', 'skills': ['SPSS', 'Microsoft Excel', 'Microsoft PowerPoint', 'Microsoft Word', 'Research', 'Leadership', 'Public Speaking', 'Capital Markets', 'Investments', 'Data Analysis', 'Data Visualization', 'Business Intelligence (BI)', 'Spreadsheets', 'Digital Marketing Analytics', 'Google Data Studio', 'SQL', 'Data Analytics']}
# User number:  563
# {'_id': 'dougmarcum', 'name': '', 'role': '', 'skills': []}
# User number:  564
# {'_id': 'surbhi-rani-2505', 'name': '', 'role': '', 'skills': []}
# User number:  565
# {'_id': 'sai-ooha-06698817a', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'Data Analysis', 'Problem Solving', 'Time Management', 'Microsoft Excel', 'Datasets', 'SQL', 'Data Warehousing', 'Data Mining', 'Statistical Data Analysis', 'Data Modeling', 'Data Management', 'Data Migration', 'Data Analytics', 'Data Visualization', 'MongoDB', 'Postman API', 'Pycharm']}
# User number:  566
# {'_id': 'conor-m-a0572844', 'name': '', 'role': '', 'skills': []}
# User number:  567
# {'_id': 'chengyu-huang-563342170', 'name': '', 'role': '', 'skills': ['Microsoft Excel', 'Research', 'Microsoft Word', 'Data Analysis', 'Statistics', 'Machine Learning', 'Finance', 'Data Mining', 'Data Visualization', 'Statistical Modeling', 'R', 'C', 'Matlab', 'SQL', 'Python (Programming Language)', 'Microsoft Office', 'Microsoft PowerPoint', 'Tableau', 'Leadership', 'Teamwork']}
# User number:  568
# {'_id': 'chaitanyapavanmaganti', 'name': '', 'role': '', 'skills': []}
# User number:  569
# {'_id': 'joe-drury18', 'name': '', 'role': '', 'skills': ['Data Analytics', 'Salesforce', 'User Experience (UX)', 'Lean Thinking', 'Web Design', 'Data Analysis', 'Software Testing', 'Computer Science', 'Psychology', 'Content Marketing', 'Writing', 'Business Development', 'Energy Industry', 'Government Contracting', 'Digital Marketing', 'Customer Relationship Management (CRM)', 'Data Mining', 'Research', 'Continuous Improvement', 'HTML5', 'Presentations', 'Technology Solutions', 'Pascal', 'Cascading Style Sheets (CSS)', 'Microsoft Visual Studio Code', 'Tkinter', 'SQL', 'Oracle SQL Developer', 'Oracle', 'English language', 'French (basic)']}
# User number:  570
# {'_id': 'fabianeaquino', 'name': '', 'role': '', 'skills': ['Recursos humanos', 'VBA', 'Relatórios KPI', 'Análise de dados', 'Remuneração e benefícios', 'Human Resources', 'Empresas startups', 'Políticas de RH', 'Implantação de sistema', 'Estratégia', 'Budget', 'Relatórios e análises', 'Microsoft Excel', 'Sistema ADP de folha de pagamento', 'Microsoft Office', 'Microsoft PowerPoint', 'Banco de dados', 'SQL', 'Personnel Supervision', 'Relações trabalhistas', 'Métricas de dashboard', 'Administração de folha de pagamento', 'Gestão de benefícios', 'Cálculos', 'Painéis do Excel', 'PowerPivot', 'Painéis de KPI', 'Fluxogramas', 'Business analytics', 'Python', 'R', 'Github', 'HTML5', 'HTML', 'JavaScript', 'Bootstrap', 'CSS', 'Google Data Studio', 'Tableau', 'MetaBase', 'Gestão']}
# User number:  571
# {'_id': 'visesh-kumar-jaiswal', 'name': '', 'role': '', 'skills': ['Python', 'C', 'C++', 'SQL', 'Java', 'HTML', 'Julia', 'MS Office', 'Visual Studio', 'Mathematica', 'MATLAB', 'MySQL', 'Linux', 'Eclipse', 'RStudio', 'Jupyter Notebook', 'Latex', 'Python (Programming Language)', 'R (Programming Language)', 'Microsoft Power BI', 'Machine Learning', 'Tableau']}
# User number:  572
# {'_id': 'camille-scaletta', 'name': '', 'role': '', 'skills': []}
# User number:  573
# {'_id': 'waltx', 'name': '', 'role': '', 'skills': ['ArcGIS', 'Water Quality', 'SWMM', 'Data Analysis', 'Data Mining', 'Statistical Data Analysis', 'Matlab', 'Quantum GIS', 'Python (Programming Language)', 'R', 'Integrated Water Resources Management', 'Water Resource Engineering', 'Scientific Data Management', 'Time Series Analysis', 'RStudio', 'Hydrologic Modeling', 'Surface Water Hydrology', 'English', 'Water Resource Management', 'Environmental Engineering', 'Research', 'Science', 'Geoprocessing', 'GIS Modeling', 'Remote Sensing', 'Engineering', 'Geographic Information Systems (GIS)', 'Microsoft Excel', 'SQL', 'Tableau', 'Microsoft Power BI', 'Resiliency', 'Analytical Skills']}
# User number:  574
# {'_id': 'ivangiangreco', 'name': '', 'role': '', 'skills': []}
# User number:  575
# {'_id': 'raunak-bhagwani', 'name': '', 'role': '', 'skills': ['Business Intelligence (BI)', 'Extract, Transform, Load (ETL)', 'Analytical Skills', 'Python (Programming Language)', 'Cascading Style Sheets (CSS)', 'Microsoft Office', 'JavaScript', 'Microsoft Excel', 'C', 'MySQL', 'PHP', 'SQL', 'Bootstrap', 'jQuery', 'HTML5', 'Unix', 'Linux', 'Databases', 'DJango', 'Microsoft SQL Server', 'Organizational Development', 'Debugging Code', 'Design Specifications', 'Product Analysis', 'MSBI', 'Business Intelligence Tools', 'Talend Open Studio', 'Data Analytics', 'Ab Initio', 'Business Analysis', 'Data Warehousing', 'DataStage', 'Requirements Analysis', 'GitHub', 'MongoDB', 'Core Java', 'Communication', 'Leadership', 'Team Leadership', 'Problem Solving', 'Organization Skills', 'Management']}
# User number:  576
# {'_id': 'krutarthpatel1997', 'name': '', 'role': '', 'skills': []}
# User number:  577
# {'_id': 'akj00768', 'name': '', 'role': '', 'skills': ['Python (Programming Language)', 'Machine Learning', 'pandas', 'NumPy', 'Linear Algebra', 'Linear Regression', 'HTML5', 'Cascading Style Sheets (CSS)', 'Statistics', 'Java']}
# User number:  578
# {'_id': 'zhishan-li-amanda', 'name': '', 'role': '', 'skills': ['Python', 'MySQL', 'Tableau', 'Cardiopulmonary Resuscitation (CPR)', 'R', 'Microsoft Excel', 'Microsoft Word', 'Microsoft Office', 'Microsoft PowerPoint', 'Git', 'Microsoft Teams', 'Microsoft Outlook', 'Python (Programming Language)', 'Leadership', 'Google Analytics', 'Customer Service', 'JavaScript', 'HTML', 'Cascading Style Sheets (CSS)', 'Presto', 'Hive', 'Apache Spark', 'Hadoop']}
# User number:  579
# {'_id': 'ramadanmalek', 'name': '', 'role': '', 'skills': ['Microsoft Excel', 'Data Analysis', 'HTML', 'Problem Solving', 'Cascading Style Sheets (CSS)', 'Python (Programming Language)', 'Adobe Photoshop', 'Teamwork', 'Structured Thinking', 'Critical Thinking']}
# User number:  580
# {'_id': 'anil-singal-556175186', 'name': '', 'role': '', 'skills': ['Data Science', 'R', 'Python (Programming Language)', 'Tableau', 'SQL', 'Microsoft Power BI', 'Excel Dashboards', 'Data Analytics', 'Data Mining', 'Data Visualization', 'Data Analysis', 'Microsoft Word', 'Microsoft Office', 'Microsoft PowerPoint', 'Microsoft Excel', 'Anaconda', 'Jupyter', 'RStudio', 'Analytical Skills', 'Problem Solving', 'Statistics', 'Google Sheets', 'Data Cleaning', 'Machine Learning', 'Pycharm', 'Extract, Transform, Load (ETL)', 'DAX', 'MySQL', 'Microsoft SQL Server', 'SQL Server Integration Services (SSIS)', 'GitHub']}
# User number:  581
# {'_id': 'jiyeshin', 'name': '', 'role': '', 'skills': ['데이터분석', '파이썬', 'SQL', '프로그래밍', 'MS 엑셀', '파이톤', '데이터 시각화', '데이터 과학', '데이터마이닝']}
# User number:  582
# {'_id': 'sarah-morris-3b40a51', 'name': '', 'role': '', 'skills': []}
# User number:  583
# {'_id': 'joe-marmo-578a6b117', 'name': '', 'role': '', 'skills': ['Teamwork', 'Microsoft Excel', 'Data Analysis', 'Reporting & Analysis', 'SQL', 'Workday']}
# User number:  584
# {'_id': 'rachel-alcorn-386b995b', 'name': '', 'role': '', 'skills': ['Human Resources', 'Management', 'Microsoft Excel', 'Insurance', 'Recruitment', 'General Insurance', 'Underwriting', 'Risk Management', 'Change Management', 'Administration', 'New Hire Orientations', 'Onboarding', 'HR Policies', 'Microsoft Office', 'Microsoft Word', 'Microsoft PowerPoint', 'Visio', 'Learning Management Systems', 'Applicant Tracking Systems', 'Microsoft Outlook', 'Time Management', 'Customer Service', 'Interviewing', 'Training', 'Coaching', 'Communication', 'Leadership', 'Teamwork', 'Public Speaking', 'Team Organisation', 'English']}
# User number:  585
# {'_id': 'yanuarega', 'name': '', 'role': '', 'skills': ['MySQL', 'Oracle SQL Developer', 'Text Mining', 'Data Mining', 'Machine Learning', 'Marketing', 'Data Science', 'Java', 'PHP', 'HTML', 'SQL', 'Matlab', 'JavaScript', 'Microsoft Word', 'Microsoft Office', 'Microsoft Excel', 'PowerPoint', 'Linux', 'Windows', 'Adobe Photoshop', 'Customer Service', 'Packet Tracer', 'Natural Language Processing (NLP)', 'Scrum', 'Project Management', 'R (Programming Language)', 'Oracle Database', 'Adobe Premiere Pro', 'Tableau', 'C (Programming Language)', 'Leadership', 'Public Speaking']}
# User number:  586
# {'_id': 'scarlettehuong', 'name': '', 'role': '', 'skills': ['Data Analysis', 'Risk Management', 'Consulting', 'Research', 'Machine Learning', 'Oracle SQL Developer', 'Python (Programming Language)', 'Critical Thinking', 'Tutoring', 'Dashboard Builder', 'GNU Octave', 'Time Management', 'Tableau', 'Looker (Software)', 'Google BigQuery']}
# User number:  587
# {'_id': 'maximosanzhernandez', 'name': '', 'role': '', 'skills': []}
# User number:  588
# {'_id': 'pnqnhu', 'name': '', 'role': '', 'skills': []}
# User number:  589
# {'_id': 'charlotte-ch%C3%A9ron-3744976b', 'name': '', 'role': '', 'skills': ['Marketing', 'Management', 'Communication marketing', 'Microsoft Office', 'Innovation product', 'Stratégie commerciale', 'Stratégie marketing', 'Stratégie', 'english', 'Microsoft Excel', 'Research', 'Gestion de projet', 'Leadership', 'PowerPoint', 'Management marketing', 'Anglais', 'Marketing Strategy', 'SPSS']}
# User number:  590
# {'_id': 'surananitish', 'name': '', 'role': '', 'skills': []}
# User number:  591
# {'_id': 'micahmbell', 'name': '', 'role': '', 'skills': []}
# User number:  592
# {'_id': 'laidunglam', 'name': '', 'role': '', 'skills': ['Data Analysis', 'Design Thinking', 'Python (Programming Language)', 'Data Structures', 'Algorithm Analysis', 'Agile Methodologies', 'Software Product Management', 'Algorithms', 'Interpersonal Communication', 'Leadership', 'Team Leadership']}
# User number:  593
# {'_id': 'omidgh2000', 'name': '', 'role': '', 'skills': []}
# User number:  594
# {'_id': 'nisa-ravi-901940108', 'name': '', 'role': '', 'skills': []}
# User number:  595
# {'_id': 'niradjani', 'name': '', 'role': '', 'skills': ['HTML', 'Java', 'JavaScript', 'Microsoft Office', 'Microsoft Excel', 'Microsoft PowerPoint', 'Microsoft Word', 'C++', 'C', 'MySQL', 'SQL', 'Customer Service', 'Management', 'Leadership', 'Teamwork', 'Python (Programming Language)', 'Eclipse', 'GitHub', 'Data Analysis', 'Tableau', 'Data Science', 'Cloud Computing', 'Microsoft SQL Server', 'Amazon Web Services (AWS)']}
# User number:  596
# {'_id': 'basem-ezz', 'name': '', 'role': '', 'skills': []}
# User number:  597
# {'_id': 'vinaykaushik7', 'name': '', 'role': '', 'skills': []}
# User number:  598
# {'_id': 'esther-suehyun-ryu', 'name': '', 'role': '', 'skills': []}
# User number:  599
# {'_id': 'adit-damodaran-1a0245108', 'name': '', 'role': '', 'skills': ['Javascript', 'Public Speaking', 'Software Development', 'Data Science', 'JavaScript', 'HTML5/CSS3', 'Python', 'React.js', 'Vue', 'Google Cloud Platform (GCP)', 'SQL', 'Photography & Videography']}
