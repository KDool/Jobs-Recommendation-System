# %%
import pandas as pd

# %%
# Read JD dataset from CSV files, Run EDA Analysis
list_data_fields = ['LinkedIn/output/JD_Business Intelligence.csv','LinkedIn/output/JD_Data Analyst.csv',
                    'LinkedIn/output/JD_Data Architect.csv','LinkedIn/output/JD_Data Engineer.csv',
                    'LinkedIn/output/JD_Data Scientist.csv','LinkedIn/output/JD_Business Analyst.csv','LinkedIn/output/JD_Database Administrator.csv']

list_software_fields = ['LinkedIn/output/JD_Back End Developer.csv','LinkedIn/output/JD_Back-end Developer.csv',
                        'LinkedIn/output/JD_DevOps.csv','LinkedIn/output/JD_Front End Developer.csv','LinkedIn/output/JD_Front-end Developer.csv',
                        'LinkedIn/output/JD_Product Manager.csv','LinkedIn/output/JD_Software Engineer.csv','LinkedIn/output/JD_Tester.csv']

# %%
def read_and_clean_single_role(input_path=''):
    df = pd.read_csv(input_path,sep='|')

    # Drop Null Values for description column
    df = df.dropna(axis=0,subset=['description'])

    # Remove the same description & company & jobTitle & location & type
    df = df.drop_duplicates(subset=['jobTitle','location','company','type','description'],keep='first')

    return df

def create_field_DataFrame(input_list = list):
    list_dfs=[]
    for item in input_list:
        print(item)
        df_tmp = read_and_clean_single_role('../'+item)
        list_dfs.append(df_tmp)

    df = pd.concat(list_dfs)
    df = df.reset_index()
    return df

# %% [markdown]
# <h3>READ Data Science JDs in English</h3>

# %%
def read_JDs(path_jobs_en='',list_fields_input=list):
    # list_jd_all_fields = list_data_fields + list_software_fields
    df1 = create_field_DataFrame(list_fields_input)
    df2 = pd.read_csv(path_jobs_en)
    return df1,df2

# %%
df1_ds,df2_ds = read_JDs('../DataPreprocessing/ds_job_lang.csv',list_fields_input=list_data_fields)
df1_ds['language'] = df2_ds['language']
df_ds = df1_ds[df1_ds['language']=='en'].reset_index(drop=True)
# Out:
# LinkedIn/output/JD_Business Intelligence.csv
# LinkedIn/output/JD_Data Analyst.csv
# LinkedIn/output/JD_Data Architect.csv
# LinkedIn/output/JD_Data Engineer.csv
# LinkedIn/output/JD_Data Scientist.csv
# LinkedIn/output/JD_Business Analyst.csv
# LinkedIn/output/JD_Database Administrator.csv

# %%
df1_sw,df2_sw = read_JDs('../DataPreprocessing/sw_job_lang.csv',list_fields_input=list_software_fields)
df1_sw['language'] = df2_sw['language']
df_sw = df1_sw[df1_sw['language']=='en'].reset_index(drop=True)
# Out:
# LinkedIn/output/JD_Back End Developer.csv
# LinkedIn/output/JD_Back-end Developer.csv
# LinkedIn/output/JD_DevOps.csv
# LinkedIn/output/JD_Front End Developer.csv
# LinkedIn/output/JD_Front-end Developer.csv
# LinkedIn/output/JD_Product Manager.csv
# LinkedIn/output/JD_Software Engineer.csv
# LinkedIn/output/JD_Tester.csv

# %%
df_ds
# Out:
#      index          id                                           jobTitle  \
# 0        0  2975673294  Data Engineer in Business Intelligence Team (B...
# 1        1  2993666500              Business Intelligence Intern, Kobiton
# 2        2  2975674182  Business Intelligence Developer, Product Team ...
# 3        3  2993740820  Business Intelligence (Edtech Company, Upto 10...
# 4        4  2945707463        Senior Business Intelligence Analyst (0824)
# ..     ...         ...                                                ...
# 427     16  2990265063     Database Administrator (DBA), based in Da Nang
# 428     17  3008519916         Junior/Senior Database Administrator (DBA)
# 429     18  2698740162             [Local Product] Database Administrator
# 430     19  2973389208  [Local Product] Database Administrator (MySQL,...
# 431     20  2990260544  Senior Database Administrator (DBA), based in ...
#
#                                         location                    company  \
# 0    Ho Chi Minh City, Ho Chi Minh City, Vietnam                      Agoda
# 1    Ho Chi Minh City, Ho Chi Minh City, Vietnam       KMS Technology, Inc.
# 2    Ho Chi Minh City, Ho Chi Minh City, Vietnam                      Agoda
# 3                          Hanoi, Hanoi, Vietnam  X3english Limited Company
# 4                          Hanoi, Hanoi, Vietnam          Techcombank (TCB)
# ..                                           ...                        ...
# 427               Đà Nang, Da Nang City, Vietnam       KMS Technology, Inc.
# 428  Ho Chi Minh City, Ho Chi Minh City, Vietnam       KMS Technology, Inc.
# 429  Ho Chi Minh City, Ho Chi Minh City, Vietnam                     Shopee
# 430  Ho Chi Minh City, Ho Chi Minh City, Vietnam                     Shopee
# 431               Đà Nang, Da Nang City, Vietnam       KMS Technology, Inc.
#
#                                                   type  \
# 0                              Full-time · Entry level
# 1                              Internship · Internship
# 2                                Full-time · Associate
# 3    ₫15,000,000/month - ₫23,000,000/month · Full-t...
# 4                                Full-time · Associate
# ..                                                 ...
# 427                              Full-time · Associate
# 428                       Full-time · Mid-Senior level
# 429                       Full-time · Mid-Senior level
# 430                            Full-time · Entry level
# 431                       Full-time · Mid-Senior level
#
#                                            description language
# 0    About the job\nAbout Agoda\n\nAgoda is an onli...       en
# 1    About the job\nThis job is sourced from a job ...       en
# 2    About the job\nAbout Agoda\n\nAgoda is an onli...       en
# 3    About the job\nThis job is sourced from a job ...       en
# 4    About the job\nJob Purpose\nThe Job Holder Res...       en
# ..                                                 ...      ...
# 427  About the job\nAs a senior DBA you will have t...       en
# 428  About the job\nAs a senior DBA you will have t...       en
# 429  About the job\nAbout The Team\n\nThe Product D...       en
# 430  About the job\nWhat Will You Do\nResponsible f...       en
# 431  About the job\nAs a senior DBA you will have t...       en
#
# [432 rows x 8 columns]

# %%
df_sw
# Out:
#      index          id                                           jobTitle  \
# 0        0  3008981684                                 Back End Developer
# 1        3  2983100486                                 Back End Developer
# 2        6  2992995558                                 Back End Developer
# 3        7  3008544604                                 Back End Developer
# 4        8  3012111122                                 Back End Developer
# ..     ...         ...                                                ...
# 642    191  2920919416                           Senior Automation Tester
# 643    192  2920916624                           Senior Automation Tester
# 644    193  2920917626                           Senior Automation Tester
# 645    194  2690306027                                QC Manager (Tester)
# 646    198  3012239765  Software Test Engineer Intern (QA/QC/Tester), ...
#
#                                 location  \
# 0              Ho Chi Minh City, Vietnam
# 1    Tân Bình, Ho Chi Minh City, Vietnam
# 2              Ho Chi Minh City, Vietnam
# 3              Ho Chi Minh City, Vietnam
# 4              Ho Chi Minh City, Vietnam
# ..                                   ...
# 642            Da Nang Metropolitan Area
# 643    Haiphong, Hai Phong City, Vietnam
# 644                Hanoi, Hanoi, Vietnam
# 645                Hanoi, Hanoi, Vietnam
# 646       Đà Nang, Da Nang City, Vietnam
#
#                                                company  \
# 0                                             Sendo.vn
# 1                                                 WATA
# 2    Axon Active - Agile Offshore Software Developm...
# 3                                                 Swop
# 4                                          MLTech Soft
# ..                                                 ...
# 642                                      EPAM Anywhere
# 643                                      EPAM Anywhere
# 644                                      EPAM Anywhere
# 645                           DAC Data Science Vietnam
# 646                               KMS Technology, Inc.
#
#                              type  \
# 0                       Full-time
# 1                       Full-time
# 2                       Full-time
# 3                       Full-time
# 4                       Full-time
# ..                            ...
# 642  Full-time · Mid-Senior level
# 643  Full-time · Mid-Senior level
# 644  Full-time · Mid-Senior level
# 645                     Full-time
# 646       Internship · Internship
#
#                                            description language
# 0    About the job\nJob description\nWrite scalable...       en
# 1    About the job\nWATA is actively looking for Mi...       en
# 2    About the job\nDescription\nComing to Axon Act...       en
# 3    About the job\n[SAIGON- VIETNAM] SWOP.COMPANY\...       en
# 4    About the job\nJOB DESCRIPTION\nFresher Back-E...       en
# ..                                                 ...      ...
# 642  About the job\nApply to this vacancy and get a...       en
# 643  About the job\nApply to this vacancy and get a...       en
# 644  About the job\nApply to this vacancy and get a...       en
# 645  About the job\nJob Description\nOversee all te...       en
# 646  About the job\nThe Brilliant Career You Love\n...       en
#
# [647 rows x 8 columns]

# %%
df_total_en = pd.concat([df_ds, df_sw], axis=0)

# %%
df_total_en.drop_duplicates(subset=['id'],keep='first',inplace=True)

# %%
df_total_en.reset_index(drop=True,inplace=True)

# %%
df_total_en.rename(columns={'id':'_id'},inplace=True)
# df_total_en

# %%
df_total_en
# Out:
#       index         _id                                           jobTitle  \
# 0         0  2975673294  Data Engineer in Business Intelligence Team (B...
# 1         1  2993666500              Business Intelligence Intern, Kobiton
# 2         2  2975674182  Business Intelligence Developer, Product Team ...
# 3         3  2993740820  Business Intelligence (Edtech Company, Upto 10...
# 4         4  2945707463        Senior Business Intelligence Analyst (0824)
# ...     ...         ...                                                ...
# 1064    191  2920919416                           Senior Automation Tester
# 1065    192  2920916624                           Senior Automation Tester
# 1066    193  2920917626                           Senior Automation Tester
# 1067    194  2690306027                                QC Manager (Tester)
# 1068    198  3012239765  Software Test Engineer Intern (QA/QC/Tester), ...
#
#                                          location                    company  \
# 0     Ho Chi Minh City, Ho Chi Minh City, Vietnam                      Agoda
# 1     Ho Chi Minh City, Ho Chi Minh City, Vietnam       KMS Technology, Inc.
# 2     Ho Chi Minh City, Ho Chi Minh City, Vietnam                      Agoda
# 3                           Hanoi, Hanoi, Vietnam  X3english Limited Company
# 4                           Hanoi, Hanoi, Vietnam          Techcombank (TCB)
# ...                                           ...                        ...
# 1064                    Da Nang Metropolitan Area              EPAM Anywhere
# 1065            Haiphong, Hai Phong City, Vietnam              EPAM Anywhere
# 1066                        Hanoi, Hanoi, Vietnam              EPAM Anywhere
# 1067                        Hanoi, Hanoi, Vietnam   DAC Data Science Vietnam
# 1068               Đà Nang, Da Nang City, Vietnam       KMS Technology, Inc.
#
#                                                    type  \
# 0                               Full-time · Entry level
# 1                               Internship · Internship
# 2                                 Full-time · Associate
# 3     ₫15,000,000/month - ₫23,000,000/month · Full-t...
# 4                                 Full-time · Associate
# ...                                                 ...
# 1064                       Full-time · Mid-Senior level
# 1065                       Full-time · Mid-Senior level
# 1066                       Full-time · Mid-Senior level
# 1067                                          Full-time
# 1068                            Internship · Internship
#
#                                             description language
# 0     About the job\nAbout Agoda\n\nAgoda is an onli...       en
# 1     About the job\nThis job is sourced from a job ...       en
# 2     About the job\nAbout Agoda\n\nAgoda is an onli...       en
# 3     About the job\nThis job is sourced from a job ...       en
# 4     About the job\nJob Purpose\nThe Job Holder Res...       en
# ...                                                 ...      ...
# 1064  About the job\nApply to this vacancy and get a...       en
# 1065  About the job\nApply to this vacancy and get a...       en
# 1066  About the job\nApply to this vacancy and get a...       en
# 1067  About the job\nJob Description\nOversee all te...       en
# 1068  About the job\nThe Brilliant Career You Love\n...       en
#
# [1069 rows x 8 columns]

# %%
keywords_tier_1  = ["yêu cầu","requirements","need to","qualifications","must have",'looking for']
keywords_tier_2  = ["skills","experience","success"]

# %%
def find_substring_pos(text='',substring=''):
    result = text.lower().find(substring)
    # print(result)
    return result

# %%
find_substring_pos("Requirements","requirements")
# Out:
# 0

# %%
def get_min_key_pos(input_dict:dict):
    # Get key-value whose value is minimum and value > -1
    min_key = -1
    min_value = max(input_dict.values())
    for key in input_dict.keys():
        if  input_dict[key] <= min_value and input_dict[key] > -1:
            # print(key,input_dict[key])
            min_value = input_dict[key]
            min_key = key
    # print(min_key,min_value)
    return min_key,min_value

# %%
d = {'skills': -1, 'experience': -1,'looking for': -1, 'success': -1}
get_min_key_pos(d)
# Out:
# (-1, -1)

# %%
def cut_jd_requirements(text=''):
    requirements_text = ''
    dictionary_tier_1 = {}
    dictionary_tier_2 = {}
    for item in keywords_tier_1:
        dictionary_tier_1[item] = find_substring_pos(text,item)
    for item in keywords_tier_2:
        dictionary_tier_2[item] = find_substring_pos(text,item)
    
    k1,v1 = get_min_key_pos(dictionary_tier_1)
    k2,v2 = get_min_key_pos(dictionary_tier_2)
    # print(dictionary_tier_1)
    # print(dictionary_tier_2)
    if v1 != -1:
        requirements_text = text[v1:-1]
    else:
        requirements_text = text[v2:-1]
    # l = list(dictionary_tier_1.values())
    # print(type(l),l)
    return requirements_text

# %%
def add_column_requirements(df:pd.DataFrame):
    cut_description_list = []
    for i in range(len(df)):
        text = df.loc[i]['description']
        requirements_text = cut_jd_requirements(text=text)
        cut_description_list.append(requirements_text)

    df['desc'] = cut_description_list
    return df

# %%
print(type(df_total_en))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = add_column_requirements(df_total_en)
# df3.rename(columns={'id':'_id'},inplace=True)
df = df[['_id','jobTitle','location','company','type','desc']]

# %%
df
# Out:
#              _id                                           jobTitle  \
# 0     2975673294  Data Engineer in Business Intelligence Team (B...
# 1     2993666500              Business Intelligence Intern, Kobiton
# 2     2975674182  Business Intelligence Developer, Product Team ...
# 3     2993740820  Business Intelligence (Edtech Company, Upto 10...
# 4     2945707463        Senior Business Intelligence Analyst (0824)
# ...          ...                                                ...
# 1064  2920919416                           Senior Automation Tester
# 1065  2920916624                           Senior Automation Tester
# 1066  2920917626                           Senior Automation Tester
# 1067  2690306027                                QC Manager (Tester)
# 1068  3012239765  Software Test Engineer Intern (QA/QC/Tester), ...
#
#                                          location                    company  \
# 0     Ho Chi Minh City, Ho Chi Minh City, Vietnam                      Agoda
# 1     Ho Chi Minh City, Ho Chi Minh City, Vietnam       KMS Technology, Inc.
# 2     Ho Chi Minh City, Ho Chi Minh City, Vietnam                      Agoda
# 3                           Hanoi, Hanoi, Vietnam  X3english Limited Company
# 4                           Hanoi, Hanoi, Vietnam          Techcombank (TCB)
# ...                                           ...                        ...
# 1064                    Da Nang Metropolitan Area              EPAM Anywhere
# 1065            Haiphong, Hai Phong City, Vietnam              EPAM Anywhere
# 1066                        Hanoi, Hanoi, Vietnam              EPAM Anywhere
# 1067                        Hanoi, Hanoi, Vietnam   DAC Data Science Vietnam
# 1068               Đà Nang, Da Nang City, Vietnam       KMS Technology, Inc.
#
#                                                    type  \
# 0                               Full-time · Entry level
# 1                               Internship · Internship
# 2                                 Full-time · Associate
# 3     ₫15,000,000/month - ₫23,000,000/month · Full-t...
# 4                                 Full-time · Associate
# ...                                                 ...
# 1064                       Full-time · Mid-Senior level
# 1065                       Full-time · Mid-Senior level
# 1066                       Full-time · Mid-Senior level
# 1067                                          Full-time
# 1068                            Internship · Internship
#
#                                                    desc
# 0     requirements. Our ultimate goal is to enable a...
# 1     need to be successful: General: * 4th year/ ne...
# 2     requirements. Our ultimate goal is to enable a...
# 3     experiences with Data Analysis or Business Ana...
# 4     requirements from within and outside of the tr...
# ...                                                 ...
# 1064  looking for a remote Senior Automation Tester ...
# 1065  looking for a remote Senior Automation Tester ...
# 1066  looking for a remote Senior Automation Tester ...
# 1067  requirements/change in requirements of the Pro...
# 1068  looking for the next destination of your testi...
#
# [1069 rows x 6 columns]

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://mongoadmin:admin@13.67.48.201:27017/")
mydb = myclient["LinkedIn"]
mycol = mydb["JobsDescription"]
mycol.insert_many(df.to_dict('records'))
