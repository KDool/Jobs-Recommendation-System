# %%
import lstm_predict
# Out:
# [nltk_data] Downloading package punkt to /Users/vankhaido/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/vankhaido/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vankhaido/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://mongoadmin:admin@13.67.48.201:27017/")
mydb = myclient["LinkedIn"]
mycol = mydb["JobsDescription"]
cursor = mycol.find()
items = list(cursor)

# mycol.insert_many(df.to_dict('records'))

# %%
import pandas as pd
df = pd.DataFrame(items)
df_desc = df[['_id','desc']]
df_desc
# Out:
#              _id                                               desc
# 0     2975673294  requirements. Our ultimate goal is to enable a...
# 1     2993666500  need to be successful: General: * 4th year/ ne...
# 2     2975674182  requirements. Our ultimate goal is to enable a...
# 3     2993740820  experiences with Data Analysis or Business Ana...
# 4     2945707463  requirements from within and outside of the tr...
# ...          ...                                                ...
# 1064  2920919416  looking for a remote Senior Automation Tester ...
# 1065  2920916624  looking for a remote Senior Automation Tester ...
# 1066  2920917626  looking for a remote Senior Automation Tester ...
# 1067  2690306027  requirements/change in requirements of the Pro...
# 1068  3012239765  looking for the next destination of your testi...
#
# [1069 rows x 2 columns]

# %%
# skills_list = lstm_predict.predict(text)
jobs_skills_result = []
for i in range(len(df_desc)):
    print("STT: ", i)
    # print(len(df_desc['desc'][i]))
    if (len(df_desc['desc'][i])>10):
        single_job_skills = lstm_predict.predict(df_desc['desc'][i])
    else:
        print("JOB DESC EMMPTY")
        single_job_skills = []
    jobs_skills_result.append(single_job_skills)

df_desc['skills'] = jobs_skills_result
# Out:
# STT:  0
# 3942
# STT:  1
# 1817
# STT:  2
# 3892
# STT:  3
# 1024
# STT:  4
# 1649
# STT:  5
# 150
# STT:  6
# 5139
# STT:  7
# 401
# STT:  8
# 1850
# STT:  9
# 591
# STT:  10
# 814
# STT:  11
# 5139
# STT:  12
# 290
# STT:  13
# 523
# STT:  14
# 404
# STT:  15
# 1839
# STT:  16
# 1017
# STT:  17
# 934
# STT:  18
# 1556
# STT:  19
# 655
# STT:  20
# 2152
# STT:  21
# 663
# STT:  22
# 5467
# STT:  23
# 934
# STT:  24
# 796
# STT:  25
# 1736
# STT:  26
# 865
# STT:  27
# 866
# STT:  28
# 615
# STT:  29
# 1467
# STT:  30
# 1311
# STT:  31
# 2393
# STT:  32
# 1755
# STT:  33
# 936
# STT:  34
# 9147
# STT:  35
# 0
# STT:  36
# 1108
# STT:  37
# 1543
# STT:  38
# 0
# STT:  39
# 521
# STT:  40
# 1759
# STT:  41
# 492
# STT:  42
# 1698
# STT:  43
# 777
# STT:  44
# 745
# STT:  45
# 2570
# STT:  46
# 4228
# STT:  47
# 3904
# STT:  48
# 745
# STT:  49
# 1074
# STT:  50
# 742
# STT:  51
# 1083
# STT:  52
# 1547
# STT:  53
# 3904
# STT:  54
# 1791
# STT:  55
# 1781
# STT:  56
# 1928
# STT:  57
# ...

# %%
skills_list
# Out:
# ['procedures',
#  'data visualisation tools',
#  'multiple stakeholders',
#  'stored procedures manage',
#  'various divisions',
#  'make inferences data',
#  'changing ities',
#  'technology products',
#  'procedures manage',
#  'write',
#  'self starter can do attitude work team',
#  'degree quantitative field',
#  'verbal communication',
#  'across various divisions',
#  'self starter can do attitude',
#  'work team',
#  'business impact',
#  'tools',
#  'excellence',
#  'data',
#  'manage multiple ities',
#  'ities',
#  'relational databases',
#  'complex queries',
#  'industry business impact',
#  'written',
#  'proficiency advance sql',
#  'inferences data',
#  'numbers',
#  'multiple ities',
#  'appropriate course actions',
#  'python',
#  'visualisation tools',
#  'large data',
#  'industry',
#  'inferences',
#  'sets',
#  'adjust',
#  'large data sets numbers',
#  'statistical analysis']

# %%
# def normalize_list(skills_list:list):
#     res = []
#     for i in range(len(skills_list)):
#         temp_str = skill_remove_qualifiers(skills_list[i])
#         # print('XXXXXX   ', temp_str)
#         temp_str = str(temp_str).strip()
#         if temp_str!='':
#             res.append(temp_str)
#     skills_list = list(set(res))
#     return skills_list


# # normalize_list(skills_list)

# %%
# normalize_list(skills_list)
