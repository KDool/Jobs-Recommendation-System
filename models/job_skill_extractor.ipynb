# %%
import lstm_predict
# Out:
# [nltk_data] Downloading package punkt to /Users/vankhaido/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/vankhaido/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vankhaido/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://mongoadmin:admin@13.67.48.201:27017/")
mydb = myclient["LinkedIn"]
mycol = mydb["JobsDescription"]
cursor = mycol.find()
items = list(cursor)

# mycol.insert_many(df.to_dict('records'))

# %%
import pandas as pd
df = pd.DataFrame(items)
df_desc = df[['_id','desc']]
df_desc
# Out:
#              _id                                               desc
# 0     2975673294  requirements. Our ultimate goal is to enable a...
# 1     2993666500  need to be successful: General: * 4th year/ ne...
# 2     2975674182  requirements. Our ultimate goal is to enable a...
# 3     2993740820  experiences with Data Analysis or Business Ana...
# 4     2945707463  requirements from within and outside of the tr...
# ...          ...                                                ...
# 1064  2920919416  looking for a remote Senior Automation Tester ...
# 1065  2920916624  looking for a remote Senior Automation Tester ...
# 1066  2920917626  looking for a remote Senior Automation Tester ...
# 1067  2690306027  requirements/change in requirements of the Pro...
# 1068  3012239765  looking for the next destination of your testi...
#
# [1069 rows x 2 columns]

# %%
# skills_list = lstm_predict.predict(text)
jobs_skills_result = []
for i in range(len(df_desc)):
    print("STT: ", i)
    # print(len(df_desc['desc'][i]))
    if (len(df_desc['desc'][i])>10):
        single_job_skills = lstm_predict.predict(df_desc['desc'][i])
    else:
        print("JOB DESC EMMPTY")
        single_job_skills = []
    jobs_skills_result.append(single_job_skills)

df_desc['skills'] = jobs_skills_result

# %%
df_desc
# Out:
#              _id                                               desc  \
# 0     2975673294  requirements. Our ultimate goal is to enable a...
# 1     2993666500  need to be successful: General: * 4th year/ ne...
# 2     2975674182  requirements. Our ultimate goal is to enable a...
# 3     2993740820  experiences with Data Analysis or Business Ana...
# 4     2945707463  requirements from within and outside of the tr...
# ...          ...                                                ...
# 1064  2920919416  looking for a remote Senior Automation Tester ...
# 1065  2920916624  looking for a remote Senior Automation Tester ...
# 1066  2920917626  looking for a remote Senior Automation Tester ...
# 1067  2690306027  requirements/change in requirements of the Pro...
# 1068  3012239765  looking for the next destination of your testi...
#
#                                                  skills
# 0     [company creative approaches, science technolo...
# 1     [statistical programming language eg python ma...
# 2     [dashboard tableau, company creative approache...
# 3     [annual vacation trip, enjoy regimes, preferen...
# 4     [diverse team data management, within outside ...
# ...                                                 ...
# 1064  [countries with, micro services, positions, fi...
# 1065  [countries with, micro services, positions, fi...
# 1066  [countries with, micro services, positions, fi...
# 1067  [income, across teams, hours month, prestigiou...
# 1068  [table tennis, blood donation, checking, next ...
#
# [1069 rows x 3 columns]

# %%
df_final = df_desc[['_id','skills']]
df_final
# Out:
#              _id                                             skills
# 0     2975673294  [company creative approaches, science technolo...
# 1     2993666500  [statistical programming language eg python ma...
# 2     2975674182  [dashboard tableau, company creative approache...
# 3     2993740820  [annual vacation trip, enjoy regimes, preferen...
# 4     2945707463  [diverse team data management, within outside ...
# ...          ...                                                ...
# 1064  2920919416  [countries with, micro services, positions, fi...
# 1065  2920916624  [countries with, micro services, positions, fi...
# 1066  2920917626  [countries with, micro services, positions, fi...
# 1067  2690306027  [income, across teams, hours month, prestigiou...
# 1068  3012239765  [table tennis, blood donation, checking, next ...
#
# [1069 rows x 2 columns]

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://mongoadmin:admin@13.67.48.201:27017/")
mydb = myclient["LinkedIn"]
mycol = mydb["JobsSkills"]
mycol.insert_many(df_final.to_dict('records'))

# %%
# normalize_list(skills_list)
text2 = """Vice Head Of Humance Resources Departmemt"""

# %%
lstm_predict.predict(text2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sr/lt1xdrls5_98kvw_5_1t783c0000gn/T/ipykernel_91124/1069833740.py in <module>
# ----> 1 lstm_predict.predict(text2)
#
# NameError: name 'lstm_predict' is not defined

# %% [markdown]
# <h2>Filter some not true skills</h2>

# %%
import pymongo
import pandas as pd
myclient = pymongo.MongoClient("mongodb://mongoadmin:admin@13.67.48.201:27017/")
mydb = myclient["LinkedIn"]
mycol = mydb["JobsSkills"]
# mycol.insert_many(df_final.to_dict('records'))
items = mycol.find()
df = pd.DataFrame(items)

# %%
df
# Out:
#              _id                                             skills
# 0     2975673294  [company creative approaches, science technolo...
# 1     2993666500  [statistical programming language eg python ma...
# 2     2975674182  [dashboard tableau, company creative approache...
# 3     2993740820  [annual vacation trip, enjoy regimes, preferen...
# 4     2945707463  [diverse team data management, within outside ...
# ...          ...                                                ...
# 1064  2920919416  [countries with, micro services, positions, fi...
# 1065  2920916624  [countries with, micro services, positions, fi...
# 1066  2920917626  [countries with, micro services, positions, fi...
# 1067  2690306027  [income, across teams, hours month, prestigiou...
# 1068  3012239765  [table tennis, blood donation, checking, next ...
#
# [1069 rows x 2 columns]

# %%
type(df.iloc[10]['skills'])
# Out:
# list

# %%
def valid_string_in_item(invalid_items:list,string_input=''):
    result = 0
    for item in invalid_items:
        if item in string_input:
            result = 1
            return result
    return result

# %%
total_list = []
for i in range(0,len(df)):
    check_list = df.iloc[i]['skills'].copy()
    drop_list = []

    invalid_string = ['pregnancy','status','gender','vacation','people','sex','salary','month','health','insurance',
                        'email','inmai','holiday','qualification','monday','tuesday','wednesday','thursday','friday','saturday','sunday']
    valid_string_list = ['english','japanese','vietnamese','foreign language','data visualization','programming language',
                        'python','sql','nosql','scrum','agile','data science',' r ','software','javascript','java','scala','data engineer','data scientist',
                        'business analysis','business analyst','data analysis','data analyst','statistic','big data','data lake','data warehouse','aws','gcp',
                        'data governance','data analysis','tensorflow','bi tools','power bi','etl','linux','unix','windows','postgresql','mysql','batch','real time',
                        'data pipeline','software engineer','software engineering','data engineering','data mining']

    for item in df.iloc[i]['skills']:
        if ('degree' in item) and (len(item)>len('degree')):
            s = item.replace('degrees','').replace('degree','').strip()
            s2 = item.split(' ')
            check_list.append('degree')
            check_list.append(s)
            check_list = check_list + s2
            check_list.remove(item)
        else:
            if valid_string_in_item(invalid_items=invalid_string,string_input = item) == 1:
                check_list.remove(item)

    check_list = list(set(check_list))
    check_list_2 = check_list.copy()

    for item in check_list:
        if item.count(" ")>=3:
            # print(item)
            for valid_item in valid_string_list:
                if valid_item in item:
                    check_list_2.append(valid_item)
            check_list_2.remove(item)
            # print(item)
            continue
        
            # print(item)
        # if 
    # print("LENGTH AFTER: ",len(check_list)) 
    total_list.append(list(set(check_list_2)))


df['new_skills'] = total_list



# # print(set(df.iloc[0]['skills']).difference(set(total_list[0])))
# print(set(total_list[1067]))
    # print("NUMBER OF DROP: ",len(drop_list))

# %%
x = 235

# %%
print(df.iloc[x]['skills'])
print(df.iloc[x]['new_skills'])

# %%
# print(set(df.iloc[x]['new_skills']).difference(set(df.iloc[x]['skills'])))
diff_list = []
for i in range(len(df)):
    # print(list(set(df.iloc[i]['new_skills']).difference(set(df.iloc[i]['skills']))))
    print(df.iloc[i]['new_skills'])
# Out:
# ['creative approaches implementation', 'sources', 'golang', 'ask details', 'automate operation tasks', 'time management', 'orientation', 'technology date data', 'jobs', 'national origin', 'multitasking', 'development', 'person', 'business users', 'bash python', 'scripting bash python', 'need', 'build data pipeline', 'company', 'sydney', 'science technology hire', 'part data department', 'field', 'decision', 'scrum', 'color', 'finance data', 'data technology', 'big data', 'advance', 'employees organization location', 'product managers', 'script', 'systems', 'inclusive environment encourages', 'pride company', 'interesting', 'ultimate goal', 'religion', 'it', 'get works', 'related', 'enterprise licenses', 'reports', 'writing', 'plays', 'data science', 'removed file details', 'insight team', 'file details', 'veteran', 'hadoop', 'protected characteristics', 'big data technologies', 'fraudulent activities data', 'rely', 'pipeline', 'etl', 'keep application file', 'make design', 'making', 'bachelor advance', 'fraudulent activities', 'results', 'achieve team', 'consider', 'committed', 'implementation powerful resources', 'data', 'powerful resources', 'pipeline language python', 'business analysis', 'hungry', 'operational analytical databases', 'pipeline bigdata platform', 'python3', 'tensorflow', 'company creative approaches', 'data pipeline', 'visibility responsive work', 'technologies', 'modeling hungry', 'support maintain data', 'supporting company', 'statistic', 'databases', 'collaboration innovation employment', 'degree', 'succeed bachelor', 'minds', 'improving search', 'plenty drives', 'organization location', 'design', 'orientations', 'sql queries', 'self motivation work', 'tools', 'etl tools', 'different backgrounds orientations', 'standard quality checklist', 'different backgrounds', 'technology data', 'data engineer', 'warehouse design', 'search', 'engineers', 'dedicated customers', 'needed make design', 'age', 'application file', 'delivered data', 'data reports role', 'race', 'providing', 'characteristics', 'contribute', 'design proper data', 'attracting', 'finance data analytics', 'new tools', 'please', 'licenses', 'unsolicited resumes', 'work', 'dis', 'manila equal employer', 'future vacancies', 'origin', 'based', 'team', 'visibility', 'third party libraries', 'many others', 'personal growth success', 'technology stack scala', 'works', 'role', 'citizenship', 'english', 'keep', 'itize', 'part scrum team', 'please send resumes', 'queue systems', 'critical business users', 'responsive work', 'bi tools', 'details', 'learn', 'ensure', 'employees', 'analytics', 'customers', 'diverse talent', 'bachelor', 'protecting', 'responsible fees', 'department', 'scala', 'part data', 'python', 'equal employment', 'cultivating']
# ['every quarter', 'attitude', 'flexible time', 'platform', 'coffee', 'bi solutions', 'talented team', 'ping pong', 'sport activities football', 'sql', 'reaching', 'fitness', 'snack instant noodles', 'ready work', 'team building', 'ones company trip', 'product improvements', 'gym', 'comfort collaboration', 'pledge', 'blood donation', 'develop', 'related fields', 'warehouse data model', 'computer science software', 'optimizing', 'passionate', 'training', 'community development activities', 'pong', 'written communication', 'growing passionate', 'hot trend technologies', 'charity', 'english perks', 'd ones', 'big data platform', 'data', 'public seminars', 'communication', 'every year', 'software', 'data model', 'motivation drive impact', 'full time technical', 'making product improvements', 'quarter', 'seminars', 'year', 'statistic', 'large data', 'verbal', 'design', 'tennis', 'cookies', 'knowing', 'statistical programming language', 'join', 'across functional borders', 'deploying', 'let', 'candies', 'football', 'successful general', 'set', 'career orientation talks', 'excel skill', 'fantastic things', 'work', 'advanced excel skill', 'sport activities', 'yoga', 'testing', 'foosball', 'model big data', 'places', 'practices', 'team', 'badminton', 'problem solving skill', 'soft', 'company trip', 'enjoy', 'functional borders', 'swimming', 'ones', 'analytical thinking', 'programming language', 'learn', 'table tennis', 'open communication', 'building reports', 'python']
# ['creative approaches implementation', 'sources', 'data tools', 'ask details', 'build insight data', 'time management', 'bi solutions', 'orientation', 'relational database write', 'platform hadoop vertica', 'jobs', 'national origin', 'multitasking', 'development', 'person', 'sql', 'business users', 'execute interpret queries', 'product achieve team', 'variety data', 'reward bi developer', 'need', 'company', 'relational database', 'sydney', 'science technology hire', 'part data department', 'field', 'decision', 'color', 'new business models', 'technical', 'advance', 'big data', 'employees organization location', 'product managers', 'equal employer', 'systems', 'inclusive environment encourages', 'pride company', 'using', 'ultimate goal', 'religion', 'interesting', 'develop', 'it', 'get works', 'related', 'business questions', 'plays', 'suggest', 'removed file details', 'insight team', 'file details', 'veteran', 'data science', 'olap', 'protected characteristics', 'fraudulent activities data', 'visualization proficient', 'rely', 'etl', 'keep application file', 'solutions', 'make design', 'making', 'bachelor advance', 'fraudulent activities', 'results', 'consider', 'committed', 'measurscaldesign', 'implementation powerful resources', 'data', 'powerful resources', 'business analysis', 'operational analytical databases', 'in house enterprise', 'curious', 'data model', 'including', 'company creative approaches', 'bi developer', 'warehouse', 'supporting company', 'requests', 'statistic', 'collaboration innovation employment', 'degree', 'succeed bachelor', 'minds', 'improving search', 'plenty drives', 'organization location', 'design', 'eg', 'report visualization role', 'orientations', 'self motivation work', 'etl tools', 'dashboard tableau', 'different backgrounds orientations', 'standard quality checklist', 'different backgrounds', 'warehouse design', 'search', 'engineers', 'dedicated customers', 'age', 'application file', 'race', 'providing', 'characteristics', 'contribute', 'attracting', 'write', 'please', 'modeling', 'support maintain solutions', 'licenses', 'interpret queries', 'unsolicited resumes', 'work', 'dis', 'proper bi solution', 'model big data', 'future vacancies', 'origin', 'based', 'business questions requests', 'team', 'interpret business questions', 'python r scala', 'visibility', 'execute', 'many others', 'personal growth success', 'works', 'citizenship', 'data modeling', 'english', 'keep', 'catching', 'itize', 'data solutions', 'part scrum team', 'analytical techniques', 'please send resumes', 'queue systems', 'critical business users', 'responsive work', 'bi tools', 'details', 'employees', 'ensure', 'bachelor', 'customers', 'diverse talent', 'protecting', 'responsible fees', 'department', 'part data', 'equal employment', 'cultivating']
# ['1 2 times', 'paid', 'travel', 'engineer', 'business', 'periodic', 'command english focus', 'tasks', 'modern equipment work', 'proficiency sql', 'analysis', 'tableau', 'science', 'detailed tasks', 'optional proficiency sql', 'enjoy', 'preferential regimes', 'focusing', 'r', 'achieve', 'allowance', 'data', 'regimes', 'modelling r', 'computer', 'enjoy regimes', 'business analysis', 'english focus', 'cuc', 'software', 'efficiency', 'parking allowance', 'command', 'equipped', 'new year', 'year', 'data analysis', 'powerbi', 'bi platforms', 'regulations', 'according regulations', 'degree', 'software engineer', 'professional environment', 'outcome', 'international general hospital']
# ['sources', 'align stakeholders', 'deep information security', 'sql building reporting', 'assisting', 'querying databases', 'sql', 'areas', 'techniques', 'new data', 'gathering techniques success', 'spark', 'impact analytical solutions', 'accuracy interact squads', 'communicating', 'key accountabilities', 'agile teams', 'technical', 'develop', 'using', 'monitor', 'needs business', 'english proficiency', 'techniques success', 'plus', 'problem', 'methodology', 'etl analysis functions', 'quantitative analysis', 'solving business', 'etl', 'analysis', 'analysis bi tools', 'r', 'qlikview', 'finance', 'data', 'issues', 'agile principles', 'và planning', 'senior tribe members', 'management', 'databases', 'degree', 'assigned tribe', 'bachelors', 'programming', 'processes tools monitor', 'tools monitor', 'digital transformation project', 'reporting và planning', 'tools', 'tableau', 'analysis assess effectiveness', 'lead identification interpretation', 'handling management data', 'tribe identify questions', 'various data sources', 'business key accountabilities', 'purpose', 'data analysis', 'risk management', 'statistics', 'principles', 'scrum methodology', 'business', 'practices', 'tribe', 'various data', 'interact squads', 'mathematics', 'success', 'pursuant techcombanks policy', 'meaningful actioninsights', 'business english proficiency', 'model performance data', 'support', 'eg r', 'bi tools', 'ensure', 'actionintelligent', 'complex analysis models', 'scala', 'insighting', 'python', 'communicate', 'outside tribe analyze', 'accuracy', 'management data']
# ['assigned', 'manner', 'senior bi member', 'manager', 'deliver projects', 'business needs']
# ['', 'sources', 'engineering finance teams', 'ask details', 'orientation', 'generate value', 'analyze', 'initiatives', 'jobs', 'national origin', 'new sources data', 'proper bi solutions', 'person', 'sql', 'metabase', 'actioninsights', 'need', 'relocation', 'data mining', 'scrum', 'shopify', 'senior leadership', 'color', 'technical', 'conclusions', 'employees organization location', 'equal employer', 'inclusive environment encourages', 'agile', 'pride company', 'religion', 'quick learner', 'related', 'reports', 'empower end users', 'scrum agile methodology', 'artificial intelligence', 'sustainscalways', 'suggest', 'data science', 'removed file details', 'file details', 'veteran', 'expedia skyscanner', 'learning statistics', 'changes', 'protected characteristics', 'optimize reports', 'way', 'bi', 'reporting', 'modelling', 'provided', 'representation data', 'influence peers', 'proactive', 'etl', 'keep application file', 'managing', 'dashboards', 'analysis', 'solutions', 'operational data', 'technologies etl tools', 'consider', 'function', 'committed', 'modelling proficient', 'step way', 'finance', 'benefit', 'helpful', 'data', 'business analysis', 'effective itization', 'turning', 'to integration', 'providing forecasts', 'commercial finance team', 'around new technologies', 'software', 'assist', 'hanoi data', 'attention detail', 'influence', 'vba', 'sharing', 'procedures', 'finance department tools', 'technologies', 'impact commercial decisions', 'technical functional statistics', 'investments', 'leader', 'language data', 'degree', 'bangkok relocation', 'collaboration innovation employment', 'java', 'succeed bachelor', 'successful candidate work', 'forecasts', 'organization location', 'complex data', 'ensuccess business person', 'accounting financial', 'analytics tools', 'measurscal communication', 'r python', 'orientations', 'odbc', 'problem solving aptitude', 'new technologies', 'entire finance organization', 'tools', 'etl tools', 'different backgrounds orientations', 'new sources', 'become', 'cultivating', 'data sources', 'different backgrounds', 'tableau', 'relational databases', 'models', 'thought leader', 'high volumes', 'age', 'push new territories', 'application file', 'race', 'providing', 'characteristics', 'major operational changes', 'attracting', 'proficient', 'write', 'please', 'analysis sql data', 'analytical capabilities', 'visualization', 'insights', 'interpret queries', 'unsolicited resumes', 'data analysis', 'dis', 'career development finance', 'led insights', 'effective training programs', 'build', 'phuket', 'statistics', 'power bi', 'future vacancies', 'enskill development', 'within finance', 'origin', 'emerging initiatives', 'jakarta', 'analytical data visualization', 'based', 'team', 'expat candidates', 'execute', 'connections', 'mathematics', 'role', 'relationships', 'trusted proactive partner', 'citizenship', 'every function', 'programming language', 'itize', 'degrees', 'advanced excel', 'please send resumes', 'business position', 'senior management', 'processes', 'details', 'facilitating', 'ranging', 'added insights', 'mining data', 'employees', 'bachelor', 'analytics', 'diverse talent', 'responsible fees', 'development targets', 'end users', 'python', 'batch scripting', 'commercial acumen', 'equal employment', 'stakeholders']
# ['documents', 'reporting', 'english communicatio', 'gathering', 'use data warehouse', 'data power', 'source data', 'analytical thinking work', 'data analyst', 'công', 'compile data', 'english', 'use data', 'bi excel solutions', 'analytical thinking', 'data', 'obtain data power', 'review', 'yêyou cầyou', 'team environment', 'power', 'work', 'warehouse', 'assess source data', 'analysis services', 'analyst']
# ['creative flexible thinking', 'accredited', 'help', 'coordinating', 'needed', 'team members', 'meet kpis', 'based', 'attending', 'metrics', 'deep analysis', 'queries', 'administrative tools', 'sql', 'give guidance business', 'translate', 'website translations', 'international remote teams', 'etl', 'analysis', 'loads', 'dashboards', 'tableau', 'multitask work', 'focus', 'remote', 'bi developer vietnam', 'customer acquisition', 'english', 'track steer progress', 'intermediate sql', 'hiring', 'data', 'close guidance', 'graduation', 'jira', 'track meet kpis', 'trello', 'translations', 'chief product officer', 'big data', 'communicate', 'including jira', 'data customer acquisition', 'macro function', '4 year university', 'intermediate verbal communication', 'work administrative tools', 'attention detail', 'transformations', 'technical recruiter india', 'including', 'progress daily standups', 'export', 'launched flagship app', 'analytics', 'work', 'monitor', 'connect world engineers', 'data loads', 'organize queries', 'interactions', 'testing', 'flagship app', 'intermediate python', 'reports', 'customer retention', 'contact job poster', 'product', 'looking', 'product officer create', 'city', 'senior engineer', 'track']
# ['written', 'attitude', 'sets', 'level seniority', 'based', 'right metrics', 'junior senior applicants', 'cross functional teams', 'sql', 'describe state business', 'discuss level seniority', 'analytical thinking', 'numbers', 'english vietnamese', 'verbal communication', 'gather', 'define', 'learn', 'large data', 'python']
# ['written', 'sets', 'procedures manage', 'technology products', 'industry business impact', 'work team', 'excellence', 'changing ities', 'manage multiple ities', 'tools', 'inferences', 'quantitative field', 'ities', 'various divisions', 'inferences data', 'relational databases', 'adjust', 'proficiency advance sql', 'numbers', 'visualisation tools', 'make inferences data', 'field', 'data visualisation tools', 'data', 'appropriate course actions', 'complex queries', 'multiple stakeholders', 'across various divisions', 'business impact', 'stored procedures manage', 'write', 'statistical analysis', 'procedures', 'verbal communication', 'multiple ities', 'industry', 'large data', 'python', 'degree', 'quantitative']
# ['', 'sources', 'engineering finance teams', 'ask details', 'orientation', 'generate value', 'analyze', 'initiatives', 'jobs', 'national origin', 'new sources data', 'proper bi solutions', 'person', 'sql', 'metabase', 'actioninsights', 'need', 'relocation', 'data mining', 'scrum', 'shopify', 'senior leadership', 'color', 'technical', 'conclusions', 'employees organization location', 'equal employer', 'inclusive environment encourages', 'agile', 'pride company', 'religion', 'quick learner', 'related', 'reports', 'empower end users', 'scrum agile methodology', 'artificial intelligence', 'sustainscalways', 'suggest', 'data science', 'removed file details', 'file details', 'veteran', 'expedia skyscanner', 'learning statistics', 'changes', 'protected characteristics', 'optimize reports', 'way', 'bi', 'reporting', 'modelling', 'provided', 'representation data', 'influence peers', 'proactive', 'etl', 'keep application file', 'managing', 'dashboards', 'analysis', 'solutions', 'operational data', 'technologies etl tools', 'consider', 'function', 'committed', 'modelling proficient', 'step way', 'finance', 'benefit', 'helpful', 'data', 'business analysis', 'effective itization', 'turning', 'to integration', 'providing forecasts', 'commercial finance team', 'around new technologies', 'software', 'assist', 'hanoi data', 'attention detail', 'influence', 'vba', 'sharing', 'procedures', 'finance department tools', 'technologies', 'impact commercial decisions', 'technical functional statistics', 'investments', 'leader', 'language data', 'degree', 'bangkok relocation', 'collaboration innovation employment', 'java', 'succeed bachelor', 'successful candidate work', 'forecasts', 'organization location', 'complex data', 'ensuccess business person', 'accounting financial', 'analytics tools', 'measurscal communication', 'r python', 'orientations', 'odbc', 'problem solving aptitude', 'new technologies', 'entire finance organization', 'tools', 'etl tools', 'different backgrounds orientations', 'new sources', 'become', 'cultivating', 'data sources', 'different backgrounds', 'tableau', 'relational databases', 'models', 'thought leader', 'high volumes', 'age', 'push new territories', 'application file', 'race', 'providing', 'characteristics', 'major operational changes', 'attracting', 'proficient', 'write', 'please', 'analysis sql data', 'analytical capabilities', 'visualization', 'insights', 'interpret queries', 'unsolicited resumes', 'data analysis', 'dis', 'career development finance', 'led insights', 'effective training programs', 'build', 'phuket', 'statistics', 'power bi', 'future vacancies', 'enskill development', 'within finance', 'origin', 'emerging initiatives', 'jakarta', 'analytical data visualization', 'based', 'team', 'expat candidates', 'execute', 'connections', 'mathematics', 'role', 'relationships', 'trusted proactive partner', 'citizenship', 'every function', 'programming language', 'itize', 'degrees', 'advanced excel', 'please send resumes', 'business position', 'senior management', 'processes', 'details', 'facilitating', 'ranging', 'added insights', 'mining data', 'employees', 'bachelor', 'analytics', 'diverse talent', 'responsible fees', 'development targets', 'end users', 'python', 'batch scripting', 'commercial acumen', 'equal employment', 'stakeholders']
# ['sql', 'data', 'computer', 'science', 'data engineer', 'data engineering', 'related field', 'python', 'information', 'bachelors', 'degree', 'agile', 'systems']
# ['dialogue', 'preferdrive ideas', 'fields', 'tools', 'eager lear', 'coordinate', 'problems', 'referred interact', 'interact', 'persuade stakeholders', 'google datastudio sql', 'university', 'minimum 1 3', 'fast paced environment', 'explain problems', 'high sense responsibility', 'work', 'powerbi', 'present findings', 'microsoft analytics tools', 'related fields', 'stakeholders']
# ['evaluating', 'troubleshooting bi models', 'bi', 'provide', 'bi systems', 'levels', 'platforms', 'existing', 'work users', 'reporting systems', 'business needs', 'developing', 'performance improvement suggestion', 'data', 'conducting', 'technical ations', 'members', 'bi models', 'improving', 'data analytics platforms', 'systems', 'analytics', 'translating business needs', 'users']
# ['paid', 'ninja logistics', 'pursuant purposes', 'regular internal activities', 'laptop employees', 'competitive income', 'city', 'privacy policy notice', 'company operations', 'data visualization tableau', 'ltd company purposes', 'senior leaders', 'based', 'market', 'training', 'provide', 'promote', 'days', 'address ninja van', 'sql', 'tools', 'received', 'consent collection', 'science', 'colleagues', 'data analytics', 'professional technical', 'work environment', 'cloud data tools', 'computer science', 'company', 'positions', 'developing', 'degree', 'pte', 'company purposes', 'understood', 'information systems', 'annual company trip', 'education', 'data', 'binh district', 'computer', 'provinces cities', 'minh city', 'set notice', 'set', 'compared market', 'notice', 'cloud data', 'performance review', 'authorised', 'online offline opportunities', 'employees', 'team leader', 'bachelor', 'analytics', 'annual townhall ceremony', 'spreading', 'personal data', 'disclose', 'tan', 'purposes', 'ho chi', 'office', 'address', 'manager', 'ac read', 'applying job', 'third party', 'tet', 'job', 'visualization tableau']
# ['power bi', 'needs', 'delivered time', 'ensure reports', 'changes', 'business', 'concerns problems', 'python and or', 'regarding changes', 'enhancements', 'product technical challenges', 'think', 'sense ownership', 'accounting', 'solving', 'testing document process', 'analytical thinking problem', 'concerns', 'problems', 'document process', 'finance', 'time', 'and or visualization', 'robust data analytics', 'keen sense ownership', 'microsoft power bi', 'dealing database advantage', 'drive determination depend', 'communication', 'manage stakeholders', 'business logics', 'bachelor', 'analytics', 'technical challenges', 'level accuracy', 'database advantage', 'economics', 'work ethic', 'fixes', 'reports', 'product', 'serve', 'python', 'degree']
# ['statistics', 'plus', 'advantage', 'scalsolutions', 'business intelligence data', 'engineering', 'synthesize data', 'mathematics someone', 'research design', 'solving', 'analytical problem', 'command englis', 'structured', 'insights data', 'logical thinking', 'mathematics', 'query language', 'added advantage', 'data', 'capacity', 'draw insights data', 'environment customer', 'quantitative qualitative sources', 'insights', 'business analytics', 'analytics', 'self motivation', 'proficiency', 'high energy', 'research design scalsolutions', 'bachelor', 'subject', 'excel power point', 'critical thinking', 'degree', 'focused', 'major quantitative subject']
# ['passion metrics', 'written', 'eg', 'bar', 'includes', 'incoming requests', 'language python', 'bi needs', 'databases postgres', 'various snacks drinks', 'happy hour', 'business partners', 'based', 'figures', 'professional constructive environment', 'high attention details', 'team building activities', 'identify bi needs', 'provided', 'sql', 'analytical', 'seller', 'scripting language python', 'analysis', 'ities', 'accurate relidata', 'oral communication', 'bi basic', 'postgres', 'r', 'providing', 'basic', 'intake', 'confident operate', 'hour', 'passion metrics figures', 'make recommendations', 'recommendations', 'based ities', 'self starter', 'labour law', 'set', 'performing impact analysis', 'impact analysis', 'translating', 'party', 'bi tools', 'performance reviews', 'multiple project areas', 'power', 'request intake', 'including', 'derive business insights', 'excel', 'right ities', 'new program manage', 'new metrics', 'requests', 'interpersonal', 'analytical approach', 'drinks', 'bi report', 'adding']
# ['written', 'attitude', 'knowing', 'right metrics', 'cross functional teams', 'sql', 'describe state business', 'role', 'analytical thinking', 'programming language', 'power pivots', 'business impact sql', 'english vietnamese', 'business impact', 'advanced', 'set', 'verbal communication', 'gather', 'define', 'analytics', 'learn', 'statistic', 'large data', 'python']
# ['enable', 'help', 'solving', 'counterparts', 'reaching', 'come', 'counterparts bi', 'country teams', 'face solutions', 'monitoring', 's', 'data analyses', 'structural solutions', 'understand', 'powerbi', 'done', 'advantage', 'bi', 'developed', 'standardized analysis trackers', 'insight', 'solutions', 'performance', 'results', 'leverage data analyses', 'data products', 'data', 'improved', 'realize', 'issues', 'communication', 'pm', 'interpersonal', 'pm automation', 'degree', 'orientated', 'developing solutions', 'e commerce', 'metrics', 'mass data', 'results detail', 'tableau', 'let', 'traffic', 'operational demand categories', 'approach', 'master', 'set', 'layered tables', 'bachelor s master', 'perceive opportunities', 'detail', 'consulting', 'setting metrics', 'data analysis', 'enhancing approach', 'country', 'blocking', 'analyses', 'job poster location', 'implemented country teams', 'statistics', 'independent thoughts', 'business', 'input country teams', 'leverage', 'business leaders', 'warehouse monitoring', 'tool sas', 'functional expertise lead', 'automation', 'structured', 'mathematics', 'trial solutions', 'emphasis problem', 'sql skill', 'fulfilment', 'spss', 'test trial solutions', 'analytics', 'bachelor', 'lazada', 'logistics']
# ['design', 'written', 'recommending management executives', 'creating', 'organization', 'implementation', 'collection software protocol', 'user manuals organization', 'achieving deadlines', 'services', 'analytical forecasting', 'deadlines', 'includes design', 'multiple projects', 'data', 'identifying development needs', 'development needs', 'purpose', 'new software programs', 'processes', 'organization efficiency profit', 'software', 'manuals', 'documentation', 'streamlining', 'itizing', 'manuals organization', 'verbal communication skill', 'management executives', 'operations', 'maintaining documentation', 'integrating']
# ['responsibilities', 'achieve goals', 'help', 'thrive', 'gathering', 'measurement tools', 'solving', 'ambitious patients', 'getting', 'separate create', 'dedicated', 'commercial analytics', 'inspired', 'insight drive optimal', 'consent', 'written authorization', 'work patients consumers', 'made business', 'arising actions fees', 'obtained actions', 'outcomes', 'accept referrals', 'deemed', 'partnering country bim', 'posted site', 'track performance', 'moment journey challenge', 'resource managements', 'strengthening leadership', 'new ambition', 'new gsk', 'candidates', 'connect', 'across boundaries', 'looking professionals', 'employment businesses', 'unique gsk combine', 'obtaining', 'fees', 'sustainshareholder returns', 'changes', 'authorization', 'establish', 'project support tasks', 'business intelligence', 'referrals', 'styles', 'leadership', 'immune system genetics', 'comes', 'insight', 'lead', 'written communication', 'drive improvement data', 'employment businesses agencies', 'trusted', 'performance', 'growing', 'making', 'transforming', 'r', 'right thing', 'data', 'unite science', 'maximize', 'improving r', 'respect vacancies', 'get', 'creative problem', 'communication', 'task jobs', 'clear ambition', 'world', 'place', 'customer', 'management', 'trusted brands', 'feel', 'believe', 'profitgrowth', 'lifees', 'quality performance measurement', 'system', 'agenda', 'billions', 'bring something', 'primary', 'support tasks', 'work patients', 'join', 'employment business agency', 'talent', 'implementation', 'd', 'impact', 'contact gsks', 'kc data', 'tracking system', 'therefore', 'connectivity', 'accountimpact', 'looking help', 'country bim', 'bi resource managements', 'evidence', 'markets', 'consumers', 'cleansing', 'vacancies', 'performed', 'competition', 'set', 'resource utilization', 'employment agencies', 'obtain', 'deliver matters', 'start', 'help gsk', 'workflow optimization activities', 'quality customer engagement', 'preventing disease', 'key activities', 'bim', 'source reports', 'internal external data', 'goals', 'high resilience agility', 'build', 'professionals', 'performing', 'lives billions', 'business', 'team', 'goal', 'means', 'strategic analytical mindset', 'new companies', 'requested line manager', 'delivering', 'clear ownership goals', 'portfolio vaccines', 'referring candidates', 'gsk', 'unprecedented change', 'commercial asset fluency', 'lives', 'science', 'emerging markets', 'efficiencies', 'lead key activities', 'role', 'internal data sources', 'provide lead', 'actions fees', 'keep', 'support profitgrowth', 'succeed', 'commercial execution', 'disease', 'actions', 'career key responsibilities', 'support', 'min', 'commercial leaders', 'secondary data', 'loc business stakeholders', 'delivered', 'improve lives billions', 'offering', 'commercial value', 'functional areas', 'ensure', 'include', 'avail data', 'lag outcomes', 'department', 'specialty medicines', 'something', 'site', 'create', 'boundaries', 'technology get']
# ['statistics', 'plus', 'advantage', 'scalsolutions', 'business intelligence data', 'engineering', 'synthesize data', 'mathematics someone', 'research design', 'solving', 'analytical problem', 'command englis', 'structured', 'insights data', 'logical thinking', 'mathematics', 'query language', 'added advantage', 'data', 'capacity', 'draw insights data', 'environment customer', 'quantitative qualitative sources', 'insights', 'business analytics', 'analytics', 'self motivation', 'proficiency', 'high energy', 'research design scalsolutions', 'bachelor', 'subject', 'excel power point', 'critical thinking', 'degree', 'focused', 'major quantitative subject']
# ['written', 'attitude', 'across regio', 'mysql', 'knowing', 'creating', 'right metrics', 'cross functional teams', 'sql', 'describe state business', 'role', 'english', 'analytical thinking', 'programming language', 'power pivots', 'business impact', 'set', 'regio', 'mysql compulsory', 'verbal communication', 'gather', 'define', 'analytics', 'learn', 'advanced excel skill', 'vietnamese', 'statistic', 'large data', 'python', 'power query', 'usthorough dashboards visualizations']
# ['interpret trends patterns', 'exponential growth', 'serve analytical purposes', 'analyze', 'provide', 'benefiting company', 'vietnam part', 'sql', 'basis compensation', 'areas', 'timely manner identify', 'focus', 'company', 'analyze results', 'inspired', 'upon requests', 'collect', 'disseminate amounts', 'using', 'operations', 'reports', 'top market rate', 'serve business stakeholders', 'world class talents', 'r', 'part', 'business stakeholders', 'data', 'pay', 'get', 'requests business stakeholders', 'team exponential growth', 'revenue p', 'use', 'analyzing datasets', 'warehouse', 'databases', 'ongoing reports', 'market rate', 'complex data', 'sets', 'opportunities recommendations', 'decision business optimizatio', 'determined use', 'locate', 'information', 'analytical', 'statistical techniques', 'statistical packages', 'recruiting', 'products', 'development maintenance data', 'patterns', 'work', 'datasets', 'brightest technology teams', 'find', 'turn', 'statistics', 'team', 'complex data sets', 'manner identify', 'banking finance industry', 'data information', 'processes', 'interpret data', 'insight business decisions', 'top level managers', 'learn', 'interpret trends', 'looking', 'winning team', 'python', 'efficient', 'l optimization', 'information insight', 'international group experts']
# ['written', 'sets', 'procedures manage', 'technology products', 'work team', 'excellence', 'changing ities', 'sql', 'visualization tools', 'tools', 'manage multiple ities', 'inferences', 'quantitative field', 'ities', 'various divisions', 'inferences data', 'relational databases', 'adjust', 'data visualization tools', 'numbers', 'make inferences data', 'field', 'data', 'associate level', 'appropriate course actions', 'complex queries', 'multiple stakeholders', 'across various divisions', 'business impact', 'advanced', 'stored procedures manage', 'write', 'statistical analysis', 'procedures', 'verbal communication', 'proficiency', 'senior level industry', 'multiple ities', 'large data', 'python', 'degree', 'quantitative']
# ['written', 'sets', 'procedures manage', 'technology products', 'work team', 'excellence', 'changing ities', 'manage multiple ities', 'visualization tools', 'tools', 'inferences', 'quantitative field', 'ities', 'various divisions', 'inferences data', 'relational databases', 'adjust', 'proficiency advance sql', 'data visualization tools', 'numbers', 'make inferences data', 'field', 'data', 'associate level', 'appropriate course actions', 'complex queries', 'multiple stakeholders', 'across various divisions', 'business impact', 'stored procedures manage', 'write', 'statistical analysis', 'procedures', 'verbal communication', 'senior level industry', 'multiple ities', 'large data', 'python', 'degree', 'quantitative']
# ['written', 'advantage', 'hubspot systems', 'role competency', 'hubspot', 'business intelligence data', 'competency', 'tim', 'sql', 'cross functional stakeholders', 'business acumen', 'young dynamic team', 'companys', 'managers', 'power pivots', 'english vietnamese', 'advanced', 'driving business impact', 'systems', 'd managers', 'analytics', 'participate companys', 'verbal']
# ['building', 'design', 'statistics', 'responsibilities', 'business process management', 'potential international career', 'practices', 'bi', 'sql queries', 'business intelligence', 'taking responsibilities', 'problem solving analytical', 'communication presentation', 'cross functional teams', 'another quantitative field', 'open environment', 'want', 'see', 'help pharma companies', 'sql', 'dynamic environment join', 'quantitative field', 'bi reporting tools', 'supported', 'exceptional verbal', 'singapore', 'science', 'warehouse design', 'handling', 'digitize', 'saas pharma', 'sophisticated', 'impact job team', 'information systems', 'mssql', 'afraid', 'ambitions', 'graduate', 'multiple projects', 'data', 'informatics', 'written communication presentation', 'supporting', 'computer', 'appropriate visual representations', 'attained', 'attention detail', 'including mssql', 'nosql', 'creative provide', 'global environment', 'want work', 'degree', 'storage platforms', 'd leadership team', 'hot spots']
# ['religion belief', 'apply', 'social cultural background', 'appliclaw encourage standards', 'thức và kỹ', 'bi', 'leadership cap model', 'job location', 'part time', 'năng lực lãnh', 'communication presentation', 'results driven handle', 'protected', 'bằng cấp bachelors', 'skill', 'perform work organisation', 'provide equality', 'fixed term work', 'role', 'english', 'computer science', 'special', 'prudential equal employer', 'race', 'finance', 'allow', 'intermediate level', 'age', 'multiple projects', 'reasonadjustments', 'interpersonal time management', 'ethnic origin', 'related field masters', 'equality', 'account context grade', 'competencies', 'dis', 'sas', 'degree']
# ['result numbers', 'effectiveness business strategy', 'someone', 'social media', 'main responsibilities', 'uncover insights', 'multiple sources', 'lead ceo', 'sql', 'areas', 'business issues opportunities', 'analysing', 'b', 'related role business', 'developing', 'business growth research', 'collect', 'important role', 'looking someone', 'develop', 'expert', 'present analysis', 'catch', 'analyzing methodology', 'answers', 'passion data analysis', 'done', 'building', 'powerpoint', 'engineering', 'methodology', 'getting job', 'applications', 'business data expert', 'analysis', 'draw conclusions', 'marketing', 'daily changes', 'mindset', 'data', 'work analytics', 'large datasets', 'business data', 'including', 'support business objectives', 'daily task', 'formed', 'job', 'eager work', 'connecting dot', 'google analytics', 'effectiveness efficiency business', 'platforms', 'tableau', 'way business', 'use data', 'and or', 'disciplines product', 'business operation structure', 'dcm', 'products', 'new database data', 'maintain database dashboards', 'visualization', 'insights', 'thought visualization', 'across disciplines', 'p2e games', 'manipulate analyze', 'trends', 'dao', 'take', 'business', 'entertainment business category', 'creatory', 'diversifying business', 'c', 'role', 'performance data', 'english', 'valued role', 'common responsibilities', 'media', 'conated', 'find answers', 'dot', 'work analytics insights', 'maintenance forecasting models', 'proficiency', 'analytics', 'passion data', 'excel', 'decision making models', 'product', 'looking', 'python', 'city', 'planning', 'operations', 'doubleclick dcm']
# ['others', 'ninja logistics', 'documents', 'responsibilities', 'sources', 'privacy policy notice', 'execute drive analytics', 'sql', 'received', 'across various sources', 'team data', 'analysts engineers', 'set notice', 'technical', 'cloud data', 'teamwork', 'integrity plan', 'customer expectations', 'optimizing dashboards', 'applying job', 'third party', 'identifying sources', 'departments responsibilities', 'changes', 'create documents', 'changes performance measures', 'accurate insights', 'dashboards', 'company purposes', 'understood', 'data', 'computer', 'notice', 'impact business initiatives', 'maintain', 'personal data', 'manage customer expectations', 'data processing', 'degree', 'ac read', 'cloud data tools', 'disclose', 'job', 'data visualization tableau', 'departments', 'tables', 'tools', 'consent collection', 'assimilating data', 'performance measures', 'data analytics', 'computer science', 'updating', 'pte', 'provide stakeholders', 'develop design models', 'set', 'authorised', 'partnerships departments responsibilities', 'initiate processes', 'technical s', 'purposes', 'visualization tableau', 'information systems teamwork', 'business communication', 'pursuant purposes', 'scorecards', 'business metrics', 'data integrity plan', 'ltd company purposes', 'data visualization', 'deadlines analytics projects', 'science', 'data analyst', 'various sources', 'give', 'design models', 'deadlines', 'information systems', 'processing', 'bachelor master', 'processes', 'projects', 'analytics', 'project management', 'requirement', 'stakeholders']
# ['present report findings', 'design', 'written', 'report system', 'power bi', 'validate test', 'presentation data visualization', 'business', 'report system fit', 'english stakeholders', 'accounting', 'sql', 'proficient spoken', 'science', 'marketing', 'data analyst', 'education bachelors', 'finance', 'achieve', 'data', 'maintain report system', 'business analysis', 'sales', 'help business', 'propose', 'communication', 'new ideas', 'visualization', 'powered jazzhr', 'process production company', 'economics', 'warehouse', 'fit', 'presentation data', 'english data', 'execute ideas', 'degree', 'jazzhr', 'data science', 'stakeholders']
# ['many offerings', 'highlights', 'data integrity', 'answer', 'dollars', 'regional sales', 'national origin', 'availlocal candidates', 'optimize', 's', 'forecast accuracy training', 'color', 'validation', 'data governance', 'share', 'child', 'equal employer', 'around world', 'bi initiatives', 'office support', 'regard race', 'performed employees', 'user', 'make life', 'roles', 'performance vs target', 'communicate focus', 'budget', 'injury unexpected events', 'success enterprise', 'in service contracts', 'retailer engagement platforms', 'different stakeholders position', 'corporate operations', 'making', 'members brands', 'related parties', 'enhancing', 'considered', 'field teams', 'time resources', 'functions', 'fit role', 'skill proficiency communication', 'management', 'ho chi', 'databases', 'bi projects', 'design', 'ensuring data points', 'outliers abnormalities', 'different sources', 'analytical', 'user collaboration', 'data sources', 'spending accounts', 'age', 'clear business sense', 'communicate users', 'business team', 'loyal fans', 'operational execution', 'efficiency', 'dependents', 'initiatives term data', 'consumer journey strategies', 'flexible savings', 'support things', 'kc', 'total sales employees', 'warehouse activities', 'database', 'analytical uses', 'identifying opportunities sales', 'along sales', 'operating', 'enjoy', 'points', 'scope', 'sales operations', 'reflects consumers', 'ensure', 'support leader team', 'trade activities', 'initiative projects', 'build databases', 'statement', 'python', 'follow findings', 'sources', 'mine analyze data', 'target analysis', 'bi manager', 'functions parties', 'dwh bi tool', 'optimization analytics', 'sql', 'collaboration', 'analysis projects', 'limited techniques', 'know', 'communicate', 'regarding answer', 'governance sensitivity expectations', 'sales report', 'takes time resources', 'process oriented', 'english communication skill', 'life choices', 'sharing session', 'via s', 'total business', 'documenting business needs', 'drive business solutions', 'diverse passions', 'dashboard show performance', 'like fit role', 'etl', 'observed trendlines', 'performance', 'exhaustive list duties', 'accounts', 'mt', 'sla kpis work', 'continue education', 'function', 'business needs', 'data points', 'line manager', 'gathering techniques', 'territory', 'work role', 'different design', 'role availlocal candidates', 'warehouse', 'adhocs analysis', 'full tim', 'bi vendors', 'dashboard', 'opportunities improvements', 'adopt child', 'abnormalities', 'information', 'engaging stakeholders', 'form', 'improvements', 'come actions', 'follow findings insights', 'rtm dashboard', 'members', 'insights', 'implemented', 'data analysis', 'source sales', 'family case illness', 'level service', 'take care', 'business intelligent', 'periods', 'needed', 'team', 'continued success enterprise', 'different stakeholders', 'execution bi', 'making data management', 'sql show communicate', 'law statements', 'adjusted', 'collaborative draw connections', 'catching', 'relocate', 'data lake', 'alignment management data', 'parties', 'passions', 'life', 'team members brands', 'employees', 'finding data', 'department', 'follow', 'report automation', 'related function', 'fuel', 'identify', 'integrity', 'help', 'company data', 'initiatives', 'areas', 'focus', 'company', 'decision', 'sales bi manager', 'mba', 'important team members', 'business process oriented', 'agreed', 'without regard race', 'organization applies', 'additional locations', 'religion', 'stakeholder', 'data science', 'generating', 'apply', 'advantage', 'additional programs', 'assigned classification statements', 'construed', 'care', '4 year', 'primary location', 'route optimization', 'marketing', 'vendor performance', 'inclusive organization applies', 'finance', 'work stakeholders', 'trendlines', 'propose quick wins', 'bi system', 'meaningful accurate insights', 'incentive payroll analysis', 'daily sales report', 'securing stakeholder', 'defined', 'f ...
# []
# ['nuances customer', 'nuances', 'needs', 'market dynamics', 'bi', 'target ingenuity perseverance', 'different customers', 'behaviour', 'prepare s', 'automation', 'give ity offline', 'expertise', 'let', 'data analytics', 'prepare s customer', 'regional functions', 'operational work', 'job poster location', 'english', 'target', 'typical customer shop', 'align convince expertise', 'native language', 'data', 'traffic management', 'know', 'communication', 'functional', 'pm', 'functions', 'ity offline', 'analytics', 'proficiency', 'customer', 'uncover things', 'project management', 'get target', 'powerful analytical excel', 'pm automation', 'ingenuity perseverance', 'across functions', 'collect information', 'align convince']
# ['written', 'mis', 'city', 'negotiation', 'analyze data', 'annual s', 'strategy', 'cti telephone infrastructure', 'business', 'outbound campaigns', 'fixed', 'sales strategy', 'medical checkup', 'fields', 'spoken leadership', 'modelling', 'presentation', 'analytical', 'financial analysis', 'analysis', 'inbound', 'voip banking', 'business products services', 'services', 'explain', 'sip', 'finance', 'outbound processes', 'dwh', 'data', 'family dependents', 'sales', 'university', 'communication', 'collect', 'relative contribution profit', 'disseminate amounts', 'insights', 'consumer finance data', 'professional transparent', 'compensations', 'analytics', 'data insights findings', 'ocs', 'reporting tools', 'economics', 'environment', 'discuss topics', 'interpret analyze data', 'sql pl etc', 'strategies', 'databases', 'findings', 'degree', 'phone allowance', 'related fields', 'routing strategies']
# []
# ['payment performance', 'many different sources', 'collecting', 'dao student', 'work', 'hanoi', 'university', 'willing learn', 'english chineses', 'type data', 'processing type data', 'teamwork', 'probationary period', 'national economics university', 'develop']
# ['sources', 'programming r', 'analyze', 'querying databases', 'privacy compliance', 'enstakeholders', 'areas', 'graph database', 'machine learning models', 'techniques', 'create maintain', 'information security', 'agile teams', 'digital transformation projects', 'model', 'using', 'data storytelling enstakeholders', 'understand', 'monitor', 'reports', 'happened', 'assist senior data', 'reporting', 'processes tools', 'modelling', 'etl analysis functions', 'quantitative analysis', 'scientists', 'analysis', 'dashboards', 'analysis bi tools', 'performance', 'business information system', 'r', 'qlikview', 'data', 'gathering techniques', 'recommendations', 'agile principles', 'data privacy compliance', 'business operation responsibilities', 'business analytics', 'management', 'statistic', 'interpret patterns', 'databases', 'degree', 'data scientist', 'thao', 'complex data', 'sets', 'cloud platform', 'google analytics', 'tools', 'tableau', 'computer science', 'presentations', 'data analysis', 'generate dashboards', 'analytical findings', 'principles', 'scrum methodology', 'pattern data', 'practices', 'business', 'data visualization', 'tibco', 'visualization tools', 'complex data sets', 'happened business', 'reports presentations', 'google', 'support', 'processes', 'qualification', 'bi tools', 'statistical models', 'bachelor', 'analytics', 'hanoi', 'data modelling', 'scala', 'data management', 'contact job poster', 'develop processes tools', 'python', 'identify', 'planning', 'data storytelling', 'aid data storytelling', 'accuracy']
# ['payment performance', 'many different sources', 'collecting', 'work', 'hanoi', 'willing learn', 'english chineses', 'processing type data', 'type data', 'teamwork', 'probationary period', 'giang', 'develop']
# ['written', 'business growth', 'apply', 'analyze complex problems', 'power bi', 'building data', 'triggered', 'target delivery spot', 'business analyst', 'actiongroups', 'vibes', 'handle', 'new things', 'internal customers stakeholders', 'querying', 'data visualization', 'plans', 'analyze', 'quick actions', 'sql', 'statistical techniques', 'visualization tools', 'li_vn', 'wide diversity dataand', 'brand teams', 'adapt', 'analysis', 'building data visualization', 'lead cross functions', 'data analyst', 'models', 'analysts', 'technical power bi', 'complex problems', 'english', 'communicate plans findings', 'business stakeholders', 'problem solving attitude', 'multiple projects', 'data', 'business analyst role', 'cross luxe brands', 'success projects', 'predict demand change', 'large datasets', 'real time analytics', 'innovative data projects', 'cross functions', 'different marketing initiatives', 'demand change', 'plans findings', 'energy', 'visualization', 'customer segmentation', 'predictive analytics', 'projects', 'using', 'try', 'command', 'spoken', 'success role data', 'analytics', 'segments', 'accelerate business growth', 'trends', 'customers', 'drive demand projects', 'data analysis', 'analyst', 'python', 'findings', 'candidate data', 'sponsors']
# ['data related internship', 'english skill ielts', 'self leading', 'native vietnamese', 'python jupyter notebook', 'join', 'data visualization', 'intermediate sql bigquery', 'quick pivot', 'written communication', 'visualization tools', 'le duan', 'high school diploma', 'education', 'data', 'ben', 'eager learn', 'business impact', 'communication', 'location friendship building', 'studio', 'transform business impact']
# ...
# ['maintenance', 'written', 'internal stakeholders', 'suite multiple products', 'responsibilities', 'europe', 'strategy', 'continuous improvement quality', 'platform', 'standards', 'within epam', 'covered', 'participate design', 'development', 'mandatory financial background', 'deal execution platforms', 'sql', 'countries with plans', 'professional development opportunities', 'expand future today', 'global product development', 'protractor', 'monitoring', 'scalautomation framework', 'technical specialists', 'remote work', 'environmental registry products', 'example selenium webdriver', 'time', 'countries with', 'successful career', 'development product groups', 'match', 'stincome', 'automated regression purposes', 'find projects', 'online remote jobs', 'leading', 'product managers', 'technical soft', 'systems', 'using', 'paid time', 'preferindividual liaise technology', 'around world epam', 'maintenance scalautomation framework', 'tools protractor', 'digital platform engineering', 'cities', 'open positions', 'flexible adapt project', 'carrying', 'building', 'new versions', 'development teams', 'advantage', 'epam', 'provides', 'manual automation review', 'meeting', 'testing processes', 'scrum sprint', 'software engineering', 'legal dependents', 'regression purposes', 'scripting tools protractor', 'skill', 'platform professionals', 'investment banks', 'technical soft language', 'ities', 'operations evaluators', 'access community experts', 'world epam', 'manual automation', 'used thousands specialists', 'communicator', 'detail oriented possess', 'cvs english please', 'followed', 'requires', 'advantage bachelors', 'computer', 'support team estimating', 'test strategy', 'shauchuk recruiter', 'identified incidents', 'java test automation', 'access internal communities', 'north america', 'software', 'executing', 'countries', 'including', 'defects', 'developers', 'meet deadlines', 'processes meet deadlines', 'ensure defects', 'america', 'calls', 'bachelors', 'java', 'detailed', 'degree', 'certification opportunities', 'teams responsibilities', 'allows', 'verbal', 'design', 'thousands', 'flexible engagement models', 'competency centers', 'attend client', 'global teams', 'developers businesses', 'join', 'language', 'soapui', 'rest client', 'ensure deadlines', 'execution platforms', 'improvements', 'analytical', 'tools', 'asia', 'deliverables', 'software development organization', 'waterfall agile methodologies', 'note', 'exposure', 'program offers', 'computer science', 'free trainings', 'aliaksandra shauchuk recruiter', 'financial services', 'jira', 'courses access', 'across north america', 'testing management tools', 'recommend improvements', 'new versions software', 'controlled', 'additional perks', 'product development', 'write', 'documentation', 'investor communication tools', 'clients', 'ensure product test', 'timely manner', 'flexible schedule', 'offer', 'today', 'work', 'serve customers', 'testing', 'business analysts', 'access', 'software engineer', 'build', 'professionals', 'specialists', 'management tools', 'competitive rewards', 'used', 'world person', 'offered projects', 'time stincome', 'testng', 'database', 'client', 'plans', 'custom test tools', 'inc', 'earning', 'automation', 'overall quality teams', 'released', 'science', 'thousands specialists', 'incidents', 'role', 'enjoy', 'deadlines', 'english', 'positions', 'jenkins', 'ui postman', 'like jira', 'position', 'added advantage', 'future today', 'qa activities', 'soap', 'advanced', 'processes', 'corporations', 'leads', 'related discipline', 'controlling test activities', 'test activities', 'projects', 'java selenium', 'applying position', 'itized dealt', 'advisory service', 'met', 'product test', 'customers', 'api testing tools', 'programming java selenium', 'looking', 'complex sql queries', 'identify', 'planning', 'forbes', 'stworkload relocation opportunities']
# ['expereince testng', 'responsibilities', 'europe', 'platform', 'within epam', 'media entertainment industry', 'covered', 'micro services', 'countries with plans', 'professional development opportunities', 'expand future today', 'multiple responsibilities', 'e2e tester', 'testing ui', 'global product development', 'selenium', 'technical specialists', 'remote work', 'scrum', 'time', 'countries with', 'successful career', 'match', 'stincome', 'find projects', 'online remote jobs', 'leading', 'technical soft', 'systems', 'paid time', 'around world epam', 'kubernetes expertise', 'digital platform engineering', 'cities', 'open positions', 'mass media', 'building', 'epam', 'provides', 'expected', 'software engineering', 'transition', 'legal dependents', 'skill', 'platform professionals', 'technical soft language', 'expertise', 'world epam', 'access community experts', 'used thousands specialists', 'cvs english please', 'regular scrum team', 'minsk', 'access internal communities', 'integration', 'north america', 'software', 'java team customer', 'countries', 'ui', 'operates', 'including', 'aws', 'perform', 'wiremock systems', 'companies', 'america', 'java', 'certification opportunities', 'allows', 'thousands', 'flexible engagement models', 'competency centers', 'qa', 'global teams', 'join', 'language', 'including automation', 'entertainment industry', 'restassured', 'owns', 'asia', 'note', 'program offers', 'internet based businesses', 'free trainings', 'courses access', 'across north america', 'additional perks', 'clients', 'testing e2e tester', 'flexible schedule', 'today', 'serve customers', 'testing', 'jmeter', 'access', 'software engineer', 'professionals', 'specialists', 'competitive rewards', 'api', 'hours', 'offered projects', 'time stincome', 'plans', 'motion picture company', 'become part', 'inc', 'earning', 'automation', 'thousands specialists', 'enjoy', 'english', 'positions', 'mass media companies', 'position', 'media', 'future today', 'projects', 'applying position', 'advisory service', 'customers', 'qa ui', 'looking', 'forbes', 'stworkload relocation opportunities']
# ['expereince testng', 'responsibilities', 'europe', 'platform', 'within epam', 'media entertainment industry', 'covered', 'micro services', 'countries with plans', 'professional development opportunities', 'expand future today', 'multiple responsibilities', 'e2e tester', 'testing ui', 'global product development', 'selenium', 'technical specialists', 'remote work', 'scrum', 'time', 'countries with', 'successful career', 'match', 'stincome', 'find projects', 'online remote jobs', 'leading', 'technical soft', 'systems', 'paid time', 'around world epam', 'kubernetes expertise', 'digital platform engineering', 'cities', 'open positions', 'mass media', 'building', 'epam', 'provides', 'expected', 'software engineering', 'transition', 'legal dependents', 'skill', 'platform professionals', 'technical soft language', 'expertise', 'world epam', 'access community experts', 'used thousands specialists', 'cvs english please', 'regular scrum team', 'minsk', 'access internal communities', 'integration', 'north america', 'software', 'java team customer', 'countries', 'ui', 'operates', 'including', 'aws', 'perform', 'wiremock systems', 'companies', 'america', 'java', 'certification opportunities', 'allows', 'thousands', 'flexible engagement models', 'competency centers', 'qa', 'global teams', 'join', 'language', 'including automation', 'entertainment industry', 'restassured', 'owns', 'asia', 'note', 'program offers', 'internet based businesses', 'free trainings', 'courses access', 'across north america', 'additional perks', 'clients', 'testing e2e tester', 'flexible schedule', 'today', 'serve customers', 'testing', 'jmeter', 'access', 'software engineer', 'professionals', 'specialists', 'competitive rewards', 'api', 'hours', 'offered projects', 'time stincome', 'plans', 'motion picture company', 'become part', 'inc', 'earning', 'automation', 'thousands specialists', 'enjoy', 'english', 'positions', 'mass media companies', 'position', 'media', 'future today', 'projects', 'applying position', 'advisory service', 'customers', 'qa ui', 'looking', 'forbes', 'stworkload relocation opportunities']
# ['expereince testng', 'responsibilities', 'europe', 'platform', 'within epam', 'media entertainment industry', 'covered', 'micro services', 'countries with plans', 'professional development opportunities', 'expand future today', 'multiple responsibilities', 'e2e tester', 'testing ui', 'global product development', 'selenium', 'technical specialists', 'remote work', 'scrum', 'time', 'countries with', 'successful career', 'match', 'stincome', 'find projects', 'online remote jobs', 'leading', 'technical soft', 'systems', 'paid time', 'around world epam', 'kubernetes expertise', 'digital platform engineering', 'cities', 'open positions', 'mass media', 'building', 'epam', 'provides', 'expected', 'software engineering', 'transition', 'legal dependents', 'skill', 'platform professionals', 'technical soft language', 'expertise', 'world epam', 'access community experts', 'used thousands specialists', 'cvs english please', 'regular scrum team', 'minsk', 'access internal communities', 'integration', 'north america', 'software', 'java team customer', 'countries', 'ui', 'operates', 'including', 'aws', 'perform', 'wiremock systems', 'companies', 'america', 'java', 'certification opportunities', 'allows', 'thousands', 'flexible engagement models', 'competency centers', 'qa', 'global teams', 'join', 'language', 'including automation', 'entertainment industry', 'restassured', 'owns', 'asia', 'note', 'program offers', 'internet based businesses', 'free trainings', 'courses access', 'across north america', 'additional perks', 'clients', 'testing e2e tester', 'flexible schedule', 'today', 'serve customers', 'testing', 'jmeter', 'access', 'software engineer', 'professionals', 'specialists', 'competitive rewards', 'api', 'hours', 'offered projects', 'time stincome', 'plans', 'motion picture company', 'become part', 'inc', 'earning', 'automation', 'thousands specialists', 'enjoy', 'english', 'positions', 'mass media companies', 'position', 'media', 'future today', 'projects', 'applying position', 'advisory service', 'customers', 'qa ui', 'looking', 'forbes', 'stworkload relocation opportunities']
# ['expereince testng', 'responsibilities', 'europe', 'platform', 'within epam', 'media entertainment industry', 'covered', 'micro services', 'countries with plans', 'professional development opportunities', 'expand future today', 'multiple responsibilities', 'e2e tester', 'testing ui', 'global product development', 'selenium', 'technical specialists', 'remote work', 'scrum', 'time', 'countries with', 'successful career', 'match', 'stincome', 'find projects', 'online remote jobs', 'leading', 'technical soft', 'systems', 'paid time', 'around world epam', 'kubernetes expertise', 'digital platform engineering', 'cities', 'open positions', 'mass media', 'building', 'epam', 'provides', 'expected', 'software engineering', 'transition', 'legal dependents', 'skill', 'platform professionals', 'technical soft language', 'expertise', 'world epam', 'access community experts', 'used thousands specialists', 'cvs english please', 'regular scrum team', 'minsk', 'access internal communities', 'integration', 'north america', 'software', 'java team customer', 'countries', 'ui', 'operates', 'including', 'aws', 'perform', 'wiremock systems', 'companies', 'america', 'java', 'certification opportunities', 'allows', 'thousands', 'flexible engagement models', 'competency centers', 'qa', 'global teams', 'join', 'language', 'including automation', 'entertainment industry', 'restassured', 'owns', 'asia', 'note', 'program offers', 'internet based businesses', 'free trainings', 'courses access', 'across north america', 'additional perks', 'clients', 'testing e2e tester', 'flexible schedule', 'today', 'serve customers', 'testing', 'jmeter', 'access', 'software engineer', 'professionals', 'specialists', 'competitive rewards', 'api', 'hours', 'offered projects', 'time stincome', 'plans', 'motion picture company', 'become part', 'inc', 'earning', 'automation', 'thousands specialists', 'enjoy', 'english', 'positions', 'mass media companies', 'position', 'media', 'future today', 'projects', 'applying position', 'advisory service', 'customers', 'qa ui', 'looking', 'forbes', 'stworkload relocation opportunities']
# ['japanese class', 'documents', 'information technology', 'review ations', 'provide', 'prescribed', 'related field', 'ba', 'scrum', 'time', 'work manager role', 'tet accordance', 'project', 'appropriate', 'technical', 'motivation manage', 'agile', 'labor law', 'brse', 'define test solutions', 'shorts', 'luxurious hotels', 'happy hours', 'women', 'computer engineering', 'teams departments', 'team members', 'coordinate managers', 'care', 'days', 'ations', 'solutions', 'january japanese allowance', 'developer', 'onboarding', 'presentation client relations', 'proposed solutions', 're plan activities', 'plan', 'computer', 'prestigious hospitals women', 'articulate problems', 'across teams', 'software', 'pm', 'attitudes', 'year', 'qc team members', 'rest', 'sponsored', 'degree', 'looking developer', 'weekly company', 'sandals', 'annual company trips', 'programming', 'development manager', 'qa', 'departments', 'necessary extra work', 'physiological rest', 'computer science', 'types', 'agile scrum environment', 'tùng lâm', 'review', 'change', 'income', 'rework', 'collaborate', 'new team members', 'test cases', 'events', 'test cases documents', 'daily weekly activities', 'conflict resolution', 'japanese', 'human relations', 'jeans', 'welcome', 'science', 'colleagues', 'quality', 'exciting events', 'support', 'project manager', 'tester', 'ensure', 'bachelor', 'hanoi', 'contact job poster', 'female staff children', 'requirement', 'level', 'company activities', 'regimen women']
# ['every quarter', 'flexible time', 'ping pong', 'tasks', 'sport activities football', 'checking', 'techniques tools', 'techniques', 'fitness', 'academic transcript', 'snack instant noodles', 'team building', 'field', 'context driven testing', 'researched', 'gym', 'pledge', 'automated checking', 'applied', 'blood donation', 'develop', 'next destination', 'security', 'building', 'responsibility challenge', 'passionate', 'training', 'community development activities', 'developed', 'kms', 'cappuccino', 'pong', 'make', 'days', 'growing passionate', 'hot trend technologies', 'assigned', 'charity', 'week', 'solutions', 'performance', 'critical logical thinking', 'forth', 'testing field work', 'testing forth', 'field work', 'public seminars', 'software', 'every year', 'testing field', 'quarter', 'including', 'maintain', 'seminars', 'year', 'perform tasks', 'testing career', 'tennis', 'cookies', 'join', 'graduated', 'tools', 'send resume', 'background', 'let', 'automation checking', 'trained', 'football', 'opportunities', 'coffee latte', 'final year students', 'career orientation talks', 'software product development', 'fantastic things', 'test', 'testing techniques tools', 'work', 'sport activities', 'yoga', 'testing', 'consulting', 'testing techniques', 'various tools', 'foosball', 'testing efficient', 'implement', 'places', 'make test', 'practices', 'testing tools', 'badminton', 'soft', 'team diverse careers', 'performance testing', 'career', 'global software products', 'execute test cases', 'table tennis', 'looking', 'efficient', 'outsourcing', 'regarding', 'attractive allowance']

# %%
df2 = df[['_id']]
df2['skills'] =  df['new_skills']
df2
# Out:
# /var/folders/sr/lt1xdrls5_98kvw_5_1t783c0000gn/T/ipykernel_91124/2612029958.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['skills'] =  df['new_skills']
#              _id                                             skills
# 0     2975673294  [creative approaches implementation, sources, ...
# 1     2993666500  [every quarter, attitude, flexible time, platf...
# 2     2975674182  [creative approaches implementation, sources, ...
# 3     2993740820  [1 2 times, paid, travel, engineer, business, ...
# 4     2945707463  [sources, align stakeholders, deep information...
# ...          ...                                                ...
# 1064  2920919416  [expereince testng, responsibilities, europe, ...
# 1065  2920916624  [expereince testng, responsibilities, europe, ...
# 1066  2920917626  [expereince testng, responsibilities, europe, ...
# 1067  2690306027  [japanese class, documents, information techno...
# 1068  3012239765  [every quarter, flexible time, ping pong, task...
#
# [1069 rows x 2 columns]

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://mongoadmin:admin@13.67.48.201:27017/")
mydb = myclient["LinkedIn"]
mycol = mydb["JobsSkills2"]
mycol.insert_many(df2.to_dict('records'))
